# %% [markdown]
# # People Matching Algortihm
#
# ## Steps to be done
#
# 1. Get the data
# 2. Tranform into usable format (pandas?)
# 3. Clean the data (extract what data is needed)
# 4.
#
# ## Step 1: Mentor Data

# %%
import pandas as pd
import random
import xlsxwriter
import warnings
warnings.simplefilter("ignore")

# %%
# reed in mentor data
df_mentor_raw = pd.read_excel(r"FY21 - Chairman Mentor Interest Form.xlsx",sheet_name="Form1")

# check out data
df_mentor_raw.shape  #(91, 41)
# Out:
# (91, 42)

# %%
def drop_nan_cols(df):
    nr = df.shape[0]
    for column in df.columns:
        if df[column].isnull().sum(axis = 0) == nr:
            df.drop([column], axis=1, inplace=True)
    return df

df_mentor_raw = drop_nan_cols(df_mentor_raw)
df_mentor_raw.shape  #(91, 29) removed 12 cols full of NaNs
# Out:
# (91, 30)

# %%
#remove start & completion time cols
df_mentor_raw.drop(["Start time", 
         "Completion time",
         "Are you a CSAP Alum?2",
         "What is your CSAP Class FY?",
         "Which track were you in?",
         "Have you mentored an Early in Career before?",
         "Any final comments or suggestions before you submit?"], 
        axis=1, inplace=True) #remove start & completion time cols
df_mentor_raw.drop([0,1], axis=0, inplace=True)

df_mentor_raw = pd.DataFrame(df_mentor_raw).set_index('Name', drop=True)

# %%
df_mentor_raw.head()
# Out:
#                          ID               Email  \
# Name
# Luc Janssen               3  lujansse@cisco.com
# Mary Catherine Dolehide   4  mdolehid@cisco.com
# Leonora Steger            5    lronga@cisco.com
# Steve Fuchs               6  stefuchs@cisco.com
# Chase Abrams              7  chabrams@cisco.com
#
#                          How many Y2 CSAP Associates are you willing to mentor?  \
# Name
# Luc Janssen                                                              1
# Mary Catherine Dolehide                                                  1
# Leonora Steger                                                           2
# Steve Fuchs                                                              2
# Chase Abrams                                                             1
#
#                         Gender  \
# Name
# Luc Janssen                  M
# Mary Catherine Dolehide      F
# Leonora Steger               F
# Steve Fuchs                  M
# Chase Abrams                 M
#
#                         What are you most likely to give in this mentoring engagement?  \
# Name
# Luc Janssen              General strategic career advice depending on m...
# Mary Catherine Dolehide  I'm flexible and will adapt to my mentee's goals;
# Leonora Steger           I'm flexible and will adapt to my mentee's goals;
# Steve Fuchs              General strategic career advice depending on m...
# Chase Abrams             I'm flexible and will adapt to my mentee's goals;
#
#                         What would you like to get out of this mentoring engagement?  \
# Name
# Luc Janssen              Reverse Mentoring (i.e getting a millennial pe...
# Mary Catherine Dolehide  To develop myself as a people manager while de...
# Leonora Steger           To develop myself as a people manager while de...
# Steve Fuchs              Reverse Mentoring (i.e getting a millennial pe...
# Chase Abrams             To develop myself as a people manager while de...
#
#                                    What is your title? Your city of residence  \
# Name
# Luc Janssen                    Partner Account Manager              Amsterdam
# Mary Catherine Dolehide              Renewals Manager      Hinsdale, Illinois
# Leonora Steger           Cisco Select Account Manager         East Northport
# Steve Fuchs              Technical Solutions Architect            Phoenix, AZ
# Chase Abrams                    Senior Account Manager                 Denver
#
#                         Your theatre?  \
# Name
# Luc Janssen                     EMEAR
# Mary Catherine Dolehide          AMER
# Leonora Steger                   AMER
# Steve Fuchs                      AMER
# Chase Abrams                     AMER
#
#                         Would you prefer a mentee in the same theatre?  ...  \
# Name                                                                    ...
# Luc Janssen                                                        Yes  ...
# Mary Catherine Dolehide                                  No preference  ...
# Leonora Steger                                           No preference  ...
# Steve Fuchs                                                        Yes  ...
# Chase Abrams                                             No preference  ...
#
#                             Your segment?  \
# Name
# Luc Janssen                       Partner
# Mary Catherine Dolehide  Service Provider
# Leonora Steger                 Commercial
# Steve Fuchs                    Commercial
# Chase Abrams             Service Provider
#
#                         What was most challenging about the engagement and how did you overcome it?  \
# Name
# Luc Janssen                                                            NaN
# Mary Catherine Dolehide                                                NaN
# Leonora Steger                                                         NaN
# Steve Fuchs              Focus differences between myself and mentee.  ...
# Chase Abrams                                                           NaN
#
#                         Your country of residence  \
# Name
# Luc Janssen                           Netherlands
# Mary Catherine Dolehide                        US
# Leonora Steger                               USA
# Steve Fuchs                         United States
# Chase Abrams                                  USA
#
#                                            What are you general strengths?  \
# Name
# Luc Janssen              Change management;Personal Brand;Critical thin...
# Mary Catherine Dolehide  Collaboration;Customer interaction;Accountabil...
# Leonora Steger           Customer interaction;Effective listening;Coach...
# Steve Fuchs                     Accountability;Coaching;Critical thinking;
# Chase Abrams             Accountability;Customer interaction;Goal setting;
#
#                                          What are your personal interests?  \
# Name
# Luc Janssen                                        Cycling;Cooking;Family;
# Mary Catherine Dolehide   Family;Individual sports (golf, running);Travel;
# Leonora Steger                                     Cooking;Family;Reading;
# Steve Fuchs                                              Photography;Pets;
# Chase Abrams             Individual sports (golf, running);Tech hobbies...
#
#                         What do you think qualifies you to be a good mentor?2  \
# Name
# Luc Janssen              Expertise, open minded (learning is a two way ...
# Mary Catherine Dolehide  Over my 30 years in technology sales for both ...
# Leonora Steger           I think a good mentor should be open to commun...
# Steve Fuchs              Listening, guidance, availability to discuss a...
# Chase Abrams             I think I'd qualify as a good mentor for many ...
#
#                         What are your early expectations from this mentoring engagement?  \
# Name
# Luc Janssen              Providing guidance for career development (bra...
# Mary Catherine Dolehide  To share my 30 years of sales experience and r...
# Leonora Steger           I have mentored before but not through a specf...
# Steve Fuchs                   not alot.  many people don't spend the time.
# Chase Abrams             I'm 36 years old and have been in technology s...
#
#                                          Your linkedIn profile link  \
# Name
# Luc Janssen               https://www.linkedin.com/in/lwjmajanssen/
# Mary Catherine Dolehide                    Mary Catherine Dolehide
# Leonora Steger           https://www.linkedin.com/in/leonorasteger/
# Steve Fuchs                             www.linkedin/in/fuchssteven
# Chase Abrams              https://www.linkedin.com/in/chase-abrams/
#
#                         Have you already mentored for the Chairman Club Mentoring Program?  \
# Name
# Luc Janssen                                                             No
# Mary Catherine Dolehide                                                 No
# Leonora Steger                                                          No
# Steve Fuchs                                                            Yes
# Chase Abrams                                                            No
#
#                         Let us know if you already have a CSAP mentee in mind
# Name
# Luc Janssen                                                            NaN
# Mary Catherine Dolehide                                                NaN
# Leonora Steger                                                         NaN
# Steve Fuchs                                                            NaN
# Chase Abrams                                                           NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# Up to this point, the dataset is clean from data we do not need for matching.

# %%
#df["colname"].isnull().values.any().sum()

df_mentor_raw.isnull().sum(axis = 0)
# Out:
# ID                                                                              0
# Email                                                                           0
# How many Y2 CSAP Associates are you willing to mentor?                          0
# Gender                                                                          0
# What are you most likely to give in this mentoring engagement?                  0
# What would you like to get out of this mentoring engagement?                    0
# What is your title?                                                             0
# Your city of residence                                                          0
# Your theatre?                                                                   0
# Would you prefer a mentee in the same theatre?                                  0
# Would you prefer a mentee in a:                                                 0
# Would you prefer a mentee of the same gender?                                   0
# Your segment?                                                                   0
# What was most challenging about the engagement and how did you overcome it?    49
# Your country of residence                                                       0
# What are you general strengths?                                                 0
# What are your personal interests?                                               0
# What do you think qualifies you to be a good mentor?2                           1
# What are your early expectations from this mentoring engagement?                3
# Your linkedIn profile link                                                      0
# Have you already mentored for the Chairman Club Mentoring Program?              0
# Let us know if you already have a CSAP mentee in mind                          77
# dtype: int64

# %%
df_mentor = df_mentor_raw[["What are you most likely to give in this mentoring engagement?",
               "What are you general strengths?",
               "What are your personal interests?"]]
#df_mentor = pd.DataFrame(df_mentor).set_index('Name', drop=True)
df_mentor.head()
# Out:
#                         What are you most likely to give in this mentoring engagement?  \
# Name
# Luc Janssen              General strategic career advice depending on m...
# Mary Catherine Dolehide  I'm flexible and will adapt to my mentee's goals;
# Leonora Steger           I'm flexible and will adapt to my mentee's goals;
# Steve Fuchs              General strategic career advice depending on m...
# Chase Abrams             I'm flexible and will adapt to my mentee's goals;
#
#                                            What are you general strengths?  \
# Name
# Luc Janssen              Change management;Personal Brand;Critical thin...
# Mary Catherine Dolehide  Collaboration;Customer interaction;Accountabil...
# Leonora Steger           Customer interaction;Effective listening;Coach...
# Steve Fuchs                     Accountability;Coaching;Critical thinking;
# Chase Abrams             Accountability;Customer interaction;Goal setting;
#
#                                          What are your personal interests?
# Name
# Luc Janssen                                        Cycling;Cooking;Family;
# Mary Catherine Dolehide   Family;Individual sports (golf, running);Travel;
# Leonora Steger                                     Cooking;Family;Reading;
# Steve Fuchs                                              Photography;Pets;
# Chase Abrams             Individual sports (golf, running);Tech hobbies...

# %%
def extract_choices(df_col):
    choices = []
    cols = set()
    data = set(df_col)
    #data = data.split(";")
    #print(data)
    for choice in data:
        choice = choice.split(";")
        choices.append(choice)
    for innerlist in choices:
        for choice in innerlist:
            if choice != "":
                cols.add(choice)    
        
    return list(cols)

give_mentor = extract_choices(df_mentor["What are you most likely to give in this mentoring engagement?"])
strengths_mentor = extract_choices(df_mentor["What are you general strengths?"])
interests_mentor = extract_choices(df_mentor["What are your personal interests?"])

# %%
# make one hot df

def encode_onehot(df_input, df_output):
    count = 0
    for answer in df_output.columns:
        if answer == "ID":
            continue
        for column in df_input.columns:
            if column == "ID":
                continue
            for result in df_input[column]:
                if answer in result: 
                    df_output.loc[df_output.index[count], answer] = 1           #.iloc[:,2:3]               
                                       
                if count == (len(df_input.index)-1):
                    count = 0
                else:
                    count += 1
    df_output = df_output.fillna(0)
    return df_output

# %% [markdown]
# ### Mentor Question 1: What are you most likely to give in this mentoring engagement?
#
# This section creates a onehot encoded dataframe of the answers given by the mentors to this question.
#
# The responses were classifies into 4 main types:
# * **General Advice**
# * **Specific Advice**
# * **Day to Day Advice**
# * **Own Advice**
#
# The following responses were edited, due to their multiple meanings:
# * **All or any of the above** --> matches all the 4 response types
# * **I'm flexible and will adapt to my mentee's goals** --> matches all the 4 response types
#
# The following responses (recorded in the "others" field) were merged as following:
# * **Contact Center knowledge transfer** -->  matches *Specific Advice*
# * **how to become a trusted advisor and support customer with strategic planning** --> matches *Own Advice*
# * **Sharing my own career journey and lessons learnt** --> matches *Own Advice*
# * **An out of the box angle back on a situation.** --> matches *Own Advice*

# %%
df_give_mentor = encode_onehot(df_mentor, pd.DataFrame([], index=df_mentor.index, columns=give_mentor))

# %%
df_give_mentor.head()
# Out:
#                          General strategic career advice depending on mentee goals  \
# Name
# Luc Janssen                                                              1
# Mary Catherine Dolehide                                                  0
# Leonora Steger                                                           0
# Steve Fuchs                                                              1
# Chase Abrams                                                             0
#
#                          all or any of the above  \
# Name
# Luc Janssen                                    0
# Mary Catherine Dolehide                        0
# Leonora Steger                                 0
# Steve Fuchs                                    0
# Chase Abrams                                   0
#
#                          I'm flexible and will adapt to my mentee's goals  \
# Name
# Luc Janssen                                                             0
# Mary Catherine Dolehide                                                 1
# Leonora Steger                                                          1
# Steve Fuchs                                                             1
# Chase Abrams                                                            1
#
#                          an out of the box angle back on a situation.   \
# Name
# Luc Janssen                                                          0
# Mary Catherine Dolehide                                              0
# Leonora Steger                                                       0
# Steve Fuchs                                                          0
# Chase Abrams                                                         0
#
#                          Specific career advice to prepare for next role  \
# Name
# Luc Janssen                                                            1
# Mary Catherine Dolehide                                                0
# Leonora Steger                                                         0
# Steve Fuchs                                                            1
# Chase Abrams                                                           0
#
#                          Tactical day to day situations & problem solving  \
# Name
# Luc Janssen                                                             1
# Mary Catherine Dolehide                                                 0
# Leonora Steger                                                          0
# Steve Fuchs                                                             1
# Chase Abrams                                                            0
#
#                          Sharing my own career journey and lessons learnt  \
# Name
# Luc Janssen                                                             1
# Mary Catherine Dolehide                                                 0
# Leonora Steger                                                          0
# Steve Fuchs                                                             1
# Chase Abrams                                                            0
#
#                          how to become a trusted advisor and support customer with strategic planning   \
# Name
# Luc Janssen                                                              0
# Mary Catherine Dolehide                                                  0
# Leonora Steger                                                           0
# Steve Fuchs                                                              0
# Chase Abrams                                                             0
#
#                          Contact Center knowledge transfer
# Name
# Luc Janssen                                              0
# Mary Catherine Dolehide                                  0
# Leonora Steger                                           0
# Steve Fuchs                                              0
# Chase Abrams                                             0

# %%
# function to combine multiple onehot encoded columns into one and optionally adding to new df
def combine_cols(df, combine_cols, add_to_df="no", combine_name=None):
    for col in combine_cols:
        if col == combine_cols[0]:
            result_list = list(df[col])
        else:
            result_list = [x + y for x, y in zip(result_list, list(df[col]))]
            
    result_list = [1 if x>1 else x for x in result_list]
            
    if type(add_to_df) == pd.core.frame.DataFrame:
        add_to_df[combine_name] = result_list
        add_to_df.set_index(df.index.values, inplace=True)
        return add_to_df
    else:
        return result_list

# %%
df_give_mentor_final = pd.DataFrame()

# combining the columns
cols = ["General strategic career advice depending on mentee goals", 
        "all or any of the above", 
        "I'm flexible and will adapt to my mentee's goals"]
df_give_mentor_final = combine_cols(df_give_mentor, cols, add_to_df=df_give_mentor_final, combine_name="general_advice")

# Specific advice
cols = ["Contact Center knowledge transfer", # own answer
        "all or any of the above", 
        "I'm flexible and will adapt to my mentee's goals",
        "Specific career advice to prepare for next role"]
df_give_mentor_final = combine_cols(df_give_mentor, cols, add_to_df=df_give_mentor_final, combine_name="specific_advice")

# Advice of day to day situations & problem solving
cols = ["Tactical day to day situations & problem solving", 
        "all or any of the above", 
        "I'm flexible and will adapt to my mentee's goals"]
df_give_mentor_final = combine_cols(df_give_mentor, cols, add_to_df=df_give_mentor_final, combine_name="day2day_advice")

# Own experience
cols = ["how to become a trusted advisor and support customer with strategic planning ", # own answer
        "Sharing my own career journey and lessons learnt", 
        "an out of the box angle back on a situation. ", # own answer
        "all or any of the above", 
        "I'm flexible and will adapt to my mentee's goals"]
df_give_mentor_final = combine_cols(df_give_mentor, cols, add_to_df=df_give_mentor_final, combine_name="own_advice")

# %% [markdown]
# This is the final one hot encoded dataframe of the answers to Mentor Question 1:

# %%
df_give_mentor_final.head()
# Out:
#                          general_advice  specific_advice  day2day_advice  \
# Luc Janssen                           1                1               1
# Mary Catherine Dolehide               1                1               1
# Leonora Steger                        1                1               1
# Steve Fuchs                           1                1               1
# Chase Abrams                          1                1               1
#
#                          own_advice
# Luc Janssen                       1
# Mary Catherine Dolehide           1
# Leonora Steger                    1
# Steve Fuchs                       1
# Chase Abrams                      1

# %% [markdown]
# ### Mentor Question 2: What are you general strengths?
#
# This section creates a onehot encoded dataframe of the answers given by the mentors to this question.
#
# The following responses (recorded in the "others" field) were merged as following:
# * **Social Media** -->  matches *Creativity/Innovation*
# * **Rapport Building** --> matches *Customer Interaction* and *Crucial Conversations*
# * **Team building** --> matches *Empowerment* and *Recognition*
# * **Collaboration** --> matches *Productivity*
# * **Accountability** --> matches *Recognition*

# %%
df_strengths_mentor = encode_onehot(df_mentor, pd.DataFrame([], index=df_mentor.index, columns=strengths_mentor))

# %%
df_strengths_mentor.head()
# Out:
#                          Time management  Team building  Influencing  \
# Name
# Luc Janssen                            0              0            0
# Mary Catherine Dolehide                0              0            0
# Leonora Steger                         0              0            0
# Steve Fuchs                            0              0            0
# Chase Abrams                           0              0            0
#
#                          Creativity / innovation  Negotiating  \
# Name
# Luc Janssen                                    0            0
# Mary Catherine Dolehide                        0            0
# Leonora Steger                                 0            0
# Steve Fuchs                                    0            0
# Chase Abrams                                   0            0
#
#                          Technical knowledge  Productivity  Design thinking  \
# Name
# Luc Janssen                                0             0                0
# Mary Catherine Dolehide                    0             0                0
# Leonora Steger                             0             0                0
# Steve Fuchs                                0             0                0
# Chase Abrams                               0             0                0
#
#                          Cross-architecture  Competitive strategy  ...  \
# Name                                                               ...
# Luc Janssen                               0                     0  ...
# Mary Catherine Dolehide                   0                     0  ...
# Leonora Steger                            0                     0  ...
# Steve Fuchs                               0                     0  ...
# Chase Abrams                              0                     0  ...
#
#                          Delegating  Story telling  Decision making  \
# Name
# Luc Janssen                       0              0                0
# Mary Catherine Dolehide           0              0                0
# Leonora Steger                    0              0                0
# Steve Fuchs                       0              0                0
# Chase Abrams                      0              0                0
#
#                          Accountability  Critical thinking  Social Media  \
# Name
# Luc Janssen                           0                  1             0
# Mary Catherine Dolehide               1                  0             0
# Leonora Steger                        0                  0             0
# Steve Fuchs                           1                  1             0
# Chase Abrams                          1                  0             0
#
#                          Coaching  Goal setting  Collaboration  \
# Name
# Luc Janssen                     0             0              0
# Mary Catherine Dolehide         0             0              1
# Leonora Steger                  1             0              0
# Steve Fuchs                     1             0              0
# Chase Abrams                    0             1              0
#
#                          Rapport Building
# Name
# Luc Janssen                             0
# Mary Catherine Dolehide                 0
# Leonora Steger                          0
# Steve Fuchs                             0
# Chase Abrams                            0
#
# [5 rows x 33 columns]

# %%
df_strengths_mentor_final = pd.DataFrame()
exclude = []

# Customer interaction & Rapport Building
cols = ["Customer interaction", 
        "Rapport Building"] # own answer
df_strengths_mentor_final = combine_cols(df_strengths_mentor, cols, add_to_df=df_strengths_mentor_final, combine_name="Customer interaction")
exclude.append(cols)

# # Enpowerment & Team Building
# cols = ["Empowerment", 
#         "Team building"] # own answer
# df_strengths_mentor_final = combine_cols(df_strengths_mentor, cols, add_to_df=df_strengths_mentor_final, combine_name="Empowerment")
# exclude.append(cols)

# Crucial Conversations & Rapport Building
cols = ["Crucial conversations", 
        "Rapport Building"] # own answer
df_strengths_mentor_final = combine_cols(df_strengths_mentor, cols, add_to_df=df_strengths_mentor_final, combine_name="Crucial conversations")
exclude.append(cols)

# # Productivity & Collaboration
# cols = ["Productivity", 
#         "Collaboration"] # own answer
# df_strengths_mentor_final = combine_cols(df_strengths_mentor, cols, add_to_df=df_strengths_mentor_final, combine_name="Productivity")
# exclude.append(cols)

# # Creativity/Innovation & Social Media
# cols = ["Creativity / innovation", 
#         "Social Media"] # own answer
# df_strengths_mentor_final = combine_cols(df_strengths_mentor, cols, add_to_df=df_strengths_mentor_final, combine_name="Creativity / innovation")
# exclude.append(cols)

# # Recognition & Team Building & Accountability
# cols = ["Recognition", 
#         "Team building", # own answer
#         "Accountability"] # own answer
# df_strengths_mentor_final = combine_cols(df_strengths_mentor, cols, add_to_df=df_strengths_mentor_final, combine_name="Recognition")
# exclude.append(cols)

exclude = [item for sublist in exclude for item in sublist]

# %%
df_strengths_mentor_final.head()
# Out:
#                          Customer interaction  Crucial conversations
# Luc Janssen                                 0                      0
# Mary Catherine Dolehide                     1                      0
# Leonora Steger                              1                      0
# Steve Fuchs                                 0                      0
# Chase Abrams                                1                      0

# %%
for column in df_strengths_mentor.columns: 
    if column not in exclude:
        df_strengths_mentor_final[column] = list(df_strengths_mentor[column])

# %%
df_strengths_mentor_final.head()
# Out:
#                          Customer interaction  Crucial conversations  \
# Luc Janssen                                 0                      0
# Mary Catherine Dolehide                     1                      0
# Leonora Steger                              1                      0
# Steve Fuchs                                 0                      0
# Chase Abrams                                1                      0
#
#                          Time management  Team building  Influencing  \
# Luc Janssen                            0              0            0
# Mary Catherine Dolehide                0              0            0
# Leonora Steger                         0              0            0
# Steve Fuchs                            0              0            0
# Chase Abrams                           0              0            0
#
#                          Creativity / innovation  Negotiating  \
# Luc Janssen                                    0            0
# Mary Catherine Dolehide                        0            0
# Leonora Steger                                 0            0
# Steve Fuchs                                    0            0
# Chase Abrams                                   0            0
#
#                          Technical knowledge  Productivity  Design thinking  \
# Luc Janssen                                0             0                0
# Mary Catherine Dolehide                    0             0                0
# Leonora Steger                             0             0                0
# Steve Fuchs                                0             0                0
# Chase Abrams                               0             0                0
#
#                          ...  Transition career path  Delegating  \
# Luc Janssen              ...                       0           0
# Mary Catherine Dolehide  ...                       0           0
# Leonora Steger           ...                       0           0
# Steve Fuchs              ...                       0           0
# Chase Abrams             ...                       0           0
#
#                          Story telling  Decision making  Accountability  \
# Luc Janssen                          0                0               0
# Mary Catherine Dolehide              0                0               1
# Leonora Steger                       0                0               0
# Steve Fuchs                          0                0               1
# Chase Abrams                         0                0               1
#
#                          Critical thinking  Social Media  Coaching  \
# Luc Janssen                              1             0         0
# Mary Catherine Dolehide                  0             0         0
# Leonora Steger                           0             0         1
# Steve Fuchs                              1             0         1
# Chase Abrams                             0             0         0
#
#                          Goal setting  Collaboration
# Luc Janssen                         0              0
# Mary Catherine Dolehide             0              1
# Leonora Steger                      0              0
# Steve Fuchs                         0              0
# Chase Abrams                        1              0
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Mentor Question 3: What are your personal interests?
#
# This section creates a onehot encoded dataframe of the answers given by the mentors to this question.
#
# The following responses (recorded in the "others" field) were merged as following:
# * **My work. I know this sounds pleasing but it is the truth** -->  no match
# * **Ranching** --> matches *Pets*
# * **Car racing** --> matches *Extreme sports (sky diving)*
# * **Creating technology video** --> matches *Tech hobbies* and *Photography*
# * **Cycling** --> matches *Individual sports (golf, running)*
# * **Automobile and Motorcycles collecting and building** --> matches *Puzzles & games*
# * **yoga** --> matches *Individual sports (golf, running)*
# * **Golf** --> matches *Individual sports (golf, running)*
# * **Boating** --> matches *Individual sports (golf, running)*
# * **Flying** --> matches *Travel*
# * **Skiing and Scuba Diving** --> matches *Extreme sports (sky diving)* and *Individual sports (golf, running)*
# * **karate** --> matches *Individual sports (golf, running)*
# * **Diving** --> matches *Extreme sports (sky diving)*

# %%
df_interests_mentor = encode_onehot(df_mentor, pd.DataFrame([], index=df_mentor.index, columns=interests_mentor))

# %%
df_interests_mentor_final = pd.DataFrame()

# Pets & Ranching
cols = ["Pets", 
        "Ranching"] # own answer
df_interests_mentor_final = combine_cols(df_interests_mentor, cols, add_to_df=df_interests_mentor_final, combine_name="Pets")
exclude.append(cols)

# Extreme sports (sky diving) & Car racing & Skiing and Scuba Diving & Diving
cols = ["Extreme sports (sky diving)",
        "Car racing",
        "Skiing and Scuba Diving",# own answer
        "Diving"] # own answer
df_interests_mentor_final = combine_cols(df_interests_mentor, cols, add_to_df=df_interests_mentor_final, combine_name="Extreme sports (sky diving)")
exclude.append(cols)

# Tech Hobbies & Creating technology video
cols = ["Tech hobbies",
        "Creating technology video"] # own answer
df_interests_mentor_final = combine_cols(df_interests_mentor, cols, add_to_df=df_interests_mentor_final, combine_name="Tech Hobbies")
exclude.append(cols)

# Photography & Creating technology video &
cols = ["Photography",
        "Creating technology video"] # own answer
df_interests_mentor_final = combine_cols(df_interests_mentor, cols, add_to_df=df_interests_mentor_final, combine_name="Photography")
exclude.append(cols)

# Individual sports (golf, running) & Creating technology video &
cols = ["Individual sports (golf, running)",
        "Cycling", # own answer
        "yoga", # own answer
        "Golf", # own answer
        "Boating", # own answer
        "Skiing and Scuba Diving", # own answer
        "karate"] # own answer
df_interests_mentor_final = combine_cols(df_interests_mentor, cols, add_to_df=df_interests_mentor_final, combine_name="Individual sports (golf, running)")
exclude.append(cols)

# Puzzles & games & Automobile and Motorcycles collecting and building
cols = ["Puzzles & games",
        "Automobile and Motorcycles collecting and building"] # own answer
df_interests_mentor_final = combine_cols(df_interests_mentor, cols, add_to_df=df_interests_mentor_final, combine_name="Puzzles & games")
exclude.append(cols)

# Travel & Flying
cols = ["Travel",
        "Flying"] # own answer
df_interests_mentor_final = combine_cols(df_interests_mentor, cols, add_to_df=df_interests_mentor_final, combine_name="Travel")
exclude.append(cols)

exclude = [item for sublist in exclude for item in sublist]

# %%
for column in df_interests_mentor.columns: 
    if column == "ID" or column == "My work. I know this sounds pleasing but it is the truth":
        continue
    if column not in exclude:
        df_interests_mentor_final[column] = list(df_interests_mentor[column])

# %%
df_interests_mentor_final.head()
# Out:
#                          Pets  Extreme sports (sky diving)  Tech Hobbies  \
# Luc Janssen                 0                            0             0
# Mary Catherine Dolehide     0                            0             0
# Leonora Steger              0                            0             0
# Steve Fuchs                 1                            0             0
# Chase Abrams                0                            0             1
#
#                          Photography  Individual sports (golf, running)  \
# Luc Janssen                        0                                  1
# Mary Catherine Dolehide            0                                  1
# Leonora Steger                     0                                  0
# Steve Fuchs                        1                                  0
# Chase Abrams                       0                                  1
#
#                          Puzzles & games  Travel  Design  Chess  \
# Luc Janssen                            0       0       0      0
# Mary Catherine Dolehide                0       1       0      0
# Leonora Steger                         0       0       0      0
# Steve Fuchs                            0       0       0      0
# Chase Abrams                           0       0       0      0
#
#                          Team sports (soccer, football)  ...  Culture  \
# Luc Janssen                                           0  ...        0
# Mary Catherine Dolehide                               0  ...        0
# Leonora Steger                                        0  ...        0
# Steve Fuchs                                           0  ...        0
# Chase Abrams                                          0  ...        0
#
#                          Politics  Working out  Religion  Music  Wine tasting  \
# Luc Janssen                     0            0         0      0             0
# Mary Catherine Dolehide         0            0         0      0             0
# Leonora Steger                  0            0         0      0             0
# Steve Fuchs                     0            0         0      0             0
# Chase Abrams                    0            1         0      0             0
#
#                          Shopping/fashion  Social networking  Cooking  Art
# Luc Janssen                             0                  0        1    0
# Mary Catherine Dolehide                 0                  0        0    0
# Leonora Steger                          0                  0        1    0
# Steve Fuchs                             0                  0        0    0
# Chase Abrams                            0                  0        0    0
#
# [5 rows x 26 columns]

# %% [markdown]
# ### Combine all three dataframes into one:

# %%
df_onehot_mentor = pd.concat([df_give_mentor_final, df_strengths_mentor_final,df_interests_mentor_final], axis=1)
df_onehot_mentor = df_onehot_mentor.reindex(sorted(df_onehot_mentor.columns), axis=1)

# %%
df_onehot_mentor.head()
# Out:
#                          Accountability  Art  Change management  Chess  \
# Luc Janssen                           0    0                  1      0
# Mary Catherine Dolehide               1    0                  0      0
# Leonora Steger                        0    0                  0      0
# Steve Fuchs                           1    0                  0      0
# Chase Abrams                          1    0                  0      0
#
#                          Coaching  Collaboration  \
# Luc Janssen                     0              0
# Mary Catherine Dolehide         0              1
# Leonora Steger                  1              0
# Steve Fuchs                     1              0
# Chase Abrams                    0              0
#
#                          Communications (public speaking)  \
# Luc Janssen                                             0
# Mary Catherine Dolehide                                 0
# Leonora Steger                                          0
# Steve Fuchs                                             0
# Chase Abrams                                            0
#
#                          Competitive strategy  Cooking  \
# Luc Janssen                                 0        1
# Mary Catherine Dolehide                     0        0
# Leonora Steger                              0        1
# Steve Fuchs                                 0        0
# Chase Abrams                                0        0
#
#                          Creativity / innovation  ...  Transition career path  \
# Luc Janssen                                    0  ...                       0
# Mary Catherine Dolehide                        0  ...                       0
# Leonora Steger                                 0  ...                       0
# Steve Fuchs                                    0  ...                       0
# Chase Abrams                                   0  ...                       0
#
#                          Travel  Volunteering  Wine tasting  \
# Luc Janssen                   0             0             0
# Mary Catherine Dolehide       1             0             0
# Leonora Steger                0             0             0
# Steve Fuchs                   0             0             0
# Chase Abrams                  0             0             0
#
#                          Work / Life balance  Working out  day2day_advice  \
# Luc Janssen                                0            0               1
# Mary Catherine Dolehide                    0            0               1
# Leonora Steger                             0            0               1
# Steve Fuchs                                0            0               1
# Chase Abrams                               0            1               1
#
#                          general_advice  own_advice  specific_advice
# Luc Janssen                           1           1                1
# Mary Catherine Dolehide               1           1                1
# Leonora Steger                        1           1                1
# Steve Fuchs                           1           1                1
# Chase Abrams                          1           1                1
#
# [5 rows x 62 columns]

# %% [markdown]
# ## Step 2 Mentee data
#
# Now we repeat the process with the Mentee data.

# %%
# reed in mentee data
df_mentee_raw = pd.read_excel(r'FY21 - Mentee Interest - Chairman Club & Hall of Fame Mentoring Program.xlsx',sheet_name='Form1')
df_mentee_raw = pd.DataFrame(df_mentee_raw).set_index('Name', drop=True)
df_mentee_raw.shape
# Out:
# (59, 24)

# %%
df_mentee_raw = drop_nan_cols(df_mentee_raw)
df_mentee_raw.shape

# no columns had all NaNs
# Out:
# (59, 24)

# %%
df_mentee = df_mentee_raw[["What are you most likely to want out of this mentoring engagement?",
               "What are the strengths you'd like to further develop?",
               "What are your personal interests?"]]

# %%
want_mentee = extract_choices(df_mentee["What are you most likely to want out of this mentoring engagement?"])
strengths_mentee = extract_choices(df_mentee["What are the strengths you'd like to further develop?"])
interests_mentee = extract_choices(df_mentee["What are your personal interests?"])

# %% [markdown]
# ### Mentee Question 1: What are you most likely to want out of this mentoring engagement?
#
# This section creates a onehot encoded dataframe of the answers given by the mentees to this question.
#
# The responses were classifies into 4 main types:
# * **General Advice**
# * **Specific Advice**
# * **Day to Day Advice**
# * **Own Advice**
#
# The following responses (recorded in the "others" field) were edited in order to not skew the people matching. If a mentee chooses this, he/she will always be more different than each of the mentors, since no mentor will meet this creteria.
# * **Form a strategic plan on how to become the best (or the mindset that will help me do)**
# * **situational experiences (wins and losses) Want to hear their perspective on how to be a good team player Want to hear their thoughts on market changes and where tech, energy and agriculture are headed.**
#
# All responses were add to the **Own Advice** type, since otherwise the data would aswell be skewed. Now it has no impact on the mentee side of data.

# %%
df_want_mentee = encode_onehot(df_mentee, pd.DataFrame([], index=df_mentee.index, columns=want_mentee))

# %%
df_want_mentee.head()
# Out:
#                                 General strategic career advice  \
# Name
# Ana Tojeiro                                                   1
# Yosephine Gita Asaria Hutauruk                                1
# Nikolaos Papadopoulos                                         1
# Lucia Caiata                                                  1
# Radhika Paliwal                                               1
#
#                                 Anything that they wish they had known in my situation  \
# Name
# Ana Tojeiro                                                                     0
# Yosephine Gita Asaria Hutauruk                                                  0
# Nikolaos Papadopoulos                                                           0
# Lucia Caiata                                                                    0
# Radhika Paliwal                                                                 0
#
#                                 Form a strategic plan on how to become the best (or the mindset that will help me do)  \
# Name
# Ana Tojeiro                                                                     0
# Yosephine Gita Asaria Hutauruk                                                  0
# Nikolaos Papadopoulos                                                           0
# Lucia Caiata                                                                    0
# Radhika Paliwal                                                                 0
#
#                                 Looking to hear about how they handle pressure, situational experiences (wins and losses) Want to hear their perspective on how to be a good team player Want to hear their thoughts on market changes and where tech, energy and agriculture are headed.   \
# Name
# Ana Tojeiro                                                                     0
# Yosephine Gita Asaria Hutauruk                                                  0
# Nikolaos Papadopoulos                                                           0
# Lucia Caiata                                                                    0
# Radhika Paliwal                                                                 0
#
#                                 Specific career advice to prepare for next role  \
# Name
# Ana Tojeiro                                                                   0
# Yosephine Gita Asaria Hutauruk                                                0
# Nikolaos Papadopoulos                                                         0
# Lucia Caiata                                                                  0
# Radhika Paliwal                                                               1
#
#                                 How one could maximize the talent and potential  \
# Name
# Ana Tojeiro                                                                   0
# Yosephine Gita Asaria Hutauruk                                                0
# Nikolaos Papadopoulos                                                         0
# Lucia Caiata                                                                  0
# Radhika Paliwal                                                               0
#
#                                 Tactical day to day situations & problem solving  \
# Name
# Ana Tojeiro                                                                    0
# Yosephine Gita Asaria Hutauruk                                                 1
# Nikolaos Papadopoulos                                                          0
# Lucia Caiata                                                                   0
# Radhika Paliwal                                                                1
#
#                                 How to build better relationships with customers and partners /
# Name
# Ana Tojeiro                                                                     0
# Yosephine Gita Asaria Hutauruk                                                  0
# Nikolaos Papadopoulos                                                           0
# Lucia Caiata                                                                    0
# Radhika Paliwal                                                                 0

# %%
df_want_mentee_final = pd.DataFrame()
exclude = []

# combining the columns
cols = ["Form a strategic plan on how to become the best (or the mindset that will help me do)", 
        "General strategic career advice", 
        "Looking to hear about how they handle pressure, situational experiences (wins and losses) Want to hear their perspective on how to be a good team player Want to hear their thoughts on market changes and where tech, energy and agriculture are headed. "]
df_want_mentee_final = combine_cols(df_want_mentee, cols, add_to_df=df_want_mentee_final, combine_name="general_advice")
exclude.append(cols)

# Specific advice
cols = ["Form a strategic plan on how to become the best (or the mindset that will help me do)", # own answer
        "Specific career advice to prepare for next role", 
        "Looking to hear about how they handle pressure, situational experiences (wins and losses) Want to hear their perspective on how to be a good team player Want to hear their thoughts on market changes and where tech, energy and agriculture are headed. ",
        "How one could maximize the talent and potential",
        "How to build better relationships with customers and partners / "]
df_want_mentee_final = combine_cols(df_want_mentee, cols, add_to_df=df_want_mentee_final, combine_name="specific_advice")
exclude.append(cols)

# Advice of day to day situations & problem solving
cols = ["Form a strategic plan on how to become the best (or the mindset that will help me do)", # own answer
        "Tactical day to day situations & problem solving", 
        "Looking to hear about how they handle pressure, situational experiences (wins and losses) Want to hear their perspective on how to be a good team player Want to hear their thoughts on market changes and where tech, energy and agriculture are headed. "]
df_want_mentee_final = combine_cols(df_want_mentee, cols, add_to_df=df_want_mentee_final, combine_name="day2day_advice")
exclude.append(cols)

# Own experience
cols = ["Form a strategic plan on how to become the best (or the mindset that will help me do)", 
        "General strategic career advice", 
        "Specific career advice to prepare for next role",
        "Tactical day to day situations & problem solving", 
        "Looking to hear about how they handle pressure, situational experiences (wins and losses) Want to hear their perspective on how to be a good team player Want to hear their thoughts on market changes and where tech, energy and agriculture are headed. ",
        "Anything that they wish they had known in my situation"]
df_want_mentee_final = combine_cols(df_want_mentee, cols, add_to_df=df_want_mentee_final, combine_name="own_advice")
exclude.append(cols)

exclude = [item for sublist in exclude for item in sublist]

# %%
for column in df_want_mentee.columns: 
    if column not in df_want_mentee_final.columns and column not in exclude:
        df_want_mentee_final[column] = list(df_want_mentee[column])

# %%
df_want_mentee_final.head()
# Out:
#                                 general_advice  specific_advice  \
# Ana Tojeiro                                  1                0
# Yosephine Gita Asaria Hutauruk               1                0
# Nikolaos Papadopoulos                        1                0
# Lucia Caiata                                 1                0
# Radhika Paliwal                              1                1
#
#                                 day2day_advice  own_advice
# Ana Tojeiro                                  0           1
# Yosephine Gita Asaria Hutauruk               1           1
# Nikolaos Papadopoulos                        0           1
# Lucia Caiata                                 0           1
# Radhika Paliwal                              1           1

# %% [markdown]
# ### Mentee Question 2: What are the strengths you'd like to further develop?
#
# This section creates a onehot encoded dataframe of the answers given by the mentees to this question.

# %%
# with ID column
df_strengths_mentee_final = encode_onehot(df_mentee, pd.DataFrame([], index=df_mentee.index, columns=strengths_mentee))

#df_strengths_mentee_final = encode_onehot(df_mentee, strengths_mentee)

# %%
df_strengths_mentee_final.head()
# Out:
#                                 Time management  Team building  Influencing  \
# Name
# Ana Tojeiro                                   0              0            1
# Yosephine Gita Asaria Hutauruk                0              0            1
# Nikolaos Papadopoulos                         0              0            0
# Lucia Caiata                                  0              0            0
# Radhika Paliwal                               0              0            0
#
#                                 Negotiating  Creativity / innovation  \
# Name
# Ana Tojeiro                               1                        0
# Yosephine Gita Asaria Hutauruk            1                        1
# Nikolaos Papadopoulos                     1                        1
# Lucia Caiata                              0                        0
# Radhika Paliwal                           0                        0
#
#                                 Technical knowledge  Productivity  \
# Name
# Ana Tojeiro                                       0             0
# Yosephine Gita Asaria Hutauruk                    1             0
# Nikolaos Papadopoulos                             1             1
# Lucia Caiata                                      0             1
# Radhika Paliwal                                   0             0
#
#                                 Design thinking  Cross-architecture  \
# Name
# Ana Tojeiro                                   0                   1
# Yosephine Gita Asaria Hutauruk                0                   0
# Nikolaos Papadopoulos                         0                   0
# Lucia Caiata                                  0                   0
# Radhika Paliwal                               0                   0
#
#                                 Competitive strategy  ...  \
# Name                                                  ...
# Ana Tojeiro                                        0  ...
# Yosephine Gita Asaria Hutauruk                     0  ...
# Nikolaos Papadopoulos                              0  ...
# Lucia Caiata                                       0  ...
# Radhika Paliwal                                    0  ...
#
#                                 Crucial conversations  Transition career path  \
# Name
# Ana Tojeiro                                         1                       0
# Yosephine Gita Asaria Hutauruk                      0                       0
# Nikolaos Papadopoulos                               0                       0
# Lucia Caiata                                        0                       1
# Radhika Paliwal                                     0                       0
#
#                                 Delegating  Story telling  Decision making  \
# Name
# Ana Tojeiro                              0              0                1
# Yosephine Gita Asaria Hutauruk           0              0                0
# Nikolaos Papadopoulos                    0              1                0
# Lucia Caiata                             1              0                0
# Radhika Paliwal                          0              0                1
#
#                                 Critical thinking  Social Media  \
# Name
# Ana Tojeiro                                     0             0
# Yosephine Gita Asaria Hutauruk                  0             0
# Nikolaos Papadopoulos                           0             0
# Lucia Caiata                                    0             0
# Radhika Paliwal                                 0             0
#
#                                 Accountability  Goal setting  Collaboration
# Name
# Ana Tojeiro                                  0             0              0
# Yosephine Gita Asaria Hutauruk               0             0              0
# Nikolaos Papadopoulos                        0             0              0
# Lucia Caiata                                 0             1              0
# Radhika Paliwal                              0             0              0
#
# [5 rows x 32 columns]

# %% [markdown]
# ### Mentee Question 3: What are your personal interests?
#
# This section creates a onehot encoded dataframe of the answers given by the mentees to this question.
#
# The following responses (recorded in the "others" field) were merged as following:
# * **Pen and Paper role-playing games (e.g. Dungeons & Dragons)** -->  matches *Puzzles & Games*
# * **Programming (just beginning to learn!)** --> matches *Tech hobbies*
# * **Coffee** --> matches *Cooking*

# %%
df_interests_mentee = encode_onehot(df_mentee, pd.DataFrame([], index=df_mentee.index, columns=interests_mentee))

# %%
df_interests_mentee.columns
# Out:
# Index(['Photography', 'Design', 'Chess', 'Team sports (soccer, football)',
#        'Individual sports (golf, running)', 'Volunteering', 'Puzzles & games',
#        'Meditation', 'Family', 'Reading',
#        'Programming (just beginning to learn!)', 'Gardening', 'Dance',
#        'Culture', 'Politics', 'Psychology ', 'Stock market',
#        'Pen and Paper role-playing games (e.g. Dungeons & Dragons)', 'Coffee',
#        'Working out', 'Travel', 'Tech hobbies', 'Religion', 'Music', 'Pets',
#        'Extreme sports (sky diving)', 'Wine tasting', 'Shopping/fashion',
#        'Social networking', 'Cooking', 'Art'],
#       dtype='object')

# %%
df_interests_mentee_final = pd.DataFrame()
exclude = []

# Pets & Ranching
cols = ["Puzzles & games", 
        "Pen and Paper role-playing games (e.g. Dungeons & Dragons)"] # own answer
df_interests_mentee_final = combine_cols(df_interests_mentee, cols, add_to_df=df_interests_mentee_final, combine_name="Puzzles & games")
exclude.append(cols)

# Extreme sports (sky diving) & Car racing & Skiing and Scuba Diving & Diving
cols = ["Cooking",
        "Coffee"] # own answer
df_interests_mentee_final = combine_cols(df_interests_mentee, cols, add_to_df=df_interests_mentee_final, combine_name="Cooking")
exclude.append(cols)

# Tech Hobbies & Creating technology video
cols = ["Tech hobbies",
        "Programming (just beginning to learn!)"] # own answer
df_interests_mentee_final = combine_cols(df_interests_mentee, cols, add_to_df=df_interests_mentee_final, combine_name="Tech Hobbies")
exclude.append(cols)

# Stock market added to Finance strengths
for mentee in df_interests_mentee.index:
    if df_interests_mentee["Stock market"][mentee] == 1:
        df_strengths_mentee_final["Finance"][mentee] = 1
exclude.append(["Stock market"])

# Stock market added to Influencing and Negotiating strengths
for mentee in df_interests_mentee.index:
    if df_interests_mentee["Psychology "].loc[mentee] == 1:
        df_strengths_mentee_final["Influencing"].loc[mentee] = 1
        df_strengths_mentee_final["Negotiating"].loc[mentee] = 1
exclude.append(["Psychology "])

exclude = [item for sublist in exclude for item in sublist]

# %%
for column in df_interests_mentee.columns: 
    if column not in exclude:
        df_interests_mentee_final[column] = list(df_interests_mentee[column])

# %%
df_interests_mentee_final.columns
# Out:
# Index(['Puzzles & games', 'Cooking', 'Tech Hobbies', 'Photography', 'Design',
#        'Chess', 'Team sports (soccer, football)',
#        'Individual sports (golf, running)', 'Volunteering', 'Meditation',
#        'Family', 'Reading', 'Gardening', 'Dance', 'Culture', 'Politics',
#        'Working out', 'Travel', 'Religion', 'Music', 'Pets',
#        'Extreme sports (sky diving)', 'Wine tasting', 'Shopping/fashion',
#        'Social networking', 'Art'],
#       dtype='object')

# %% [markdown]
# ### Combine all three dataframes into one:

# %%
df_onehot_mentee = pd.concat([df_want_mentee_final, df_strengths_mentee_final, df_interests_mentee_final], axis=1)
df_onehot_mentee = df_onehot_mentee.reindex(sorted(df_onehot_mentee.columns), axis=1)

# %%
df_onehot_mentee.head()
# Out:
#                                 Accountability  Art  Change management  Chess  \
# Name
# Ana Tojeiro                                  0    0                  0      0
# Yosephine Gita Asaria Hutauruk               0    1                  0      0
# Nikolaos Papadopoulos                        0    0                  0      0
# Lucia Caiata                                 0    0                  0      0
# Radhika Paliwal                              0    1                  0      0
#
#                                 Coaching  Collaboration  \
# Name
# Ana Tojeiro                            0              0
# Yosephine Gita Asaria Hutauruk         0              0
# Nikolaos Papadopoulos                  0              0
# Lucia Caiata                           0              0
# Radhika Paliwal                        0              0
#
#                                 Communications (public speaking)  \
# Name
# Ana Tojeiro                                                    0
# Yosephine Gita Asaria Hutauruk                                 0
# Nikolaos Papadopoulos                                          0
# Lucia Caiata                                                   0
# Radhika Paliwal                                                1
#
#                                 Competitive strategy  Cooking  \
# Name
# Ana Tojeiro                                        0        0
# Yosephine Gita Asaria Hutauruk                     0        0
# Nikolaos Papadopoulos                              0        0
# Lucia Caiata                                       0        1
# Radhika Paliwal                                    0        0
#
#                                 Creativity / innovation  ...  \
# Name                                                     ...
# Ana Tojeiro                                           0  ...
# Yosephine Gita Asaria Hutauruk                        1  ...
# Nikolaos Papadopoulos                                 1  ...
# Lucia Caiata                                          0  ...
# Radhika Paliwal                                       0  ...
#
#                                 Transition career path  Travel  Volunteering  \
# Name
# Ana Tojeiro                                          0       1             1
# Yosephine Gita Asaria Hutauruk                       0       0             0
# Nikolaos Papadopoulos                                0       0             0
# Lucia Caiata                                         1       0             0
# Radhika Paliwal                                      0       1             0
#
#                                 Wine tasting  Work / Life balance  \
# Name
# Ana Tojeiro                                0                    0
# Yosephine Gita Asaria Hutauruk             0                    0
# Nikolaos Papadopoulos                      0                    0
# Lucia Caiata                               0                    1
# Radhika Paliwal                            0                    0
#
#                                 Working out  day2day_advice  general_advice  \
# Name
# Ana Tojeiro                               0               0               1
# Yosephine Gita Asaria Hutauruk            1               1               1
# Nikolaos Papadopoulos                     0               0               1
# Lucia Caiata                              0               0               1
# Radhika Paliwal                           1               1               1
#
#                                 own_advice  specific_advice
# Name
# Ana Tojeiro                              1                0
# Yosephine Gita Asaria Hutauruk           1                0
# Nikolaos Papadopoulos                    1                0
# Lucia Caiata                             1                0
# Radhika Paliwal                          1                1
#
# [5 rows x 62 columns]

# %% [markdown]
# # Check the dataframes for errors

# %%
df_interests_mentee_final.columns
# Out:
# Index(['Puzzles & games', 'Cooking', 'Tech Hobbies', 'Photography', 'Design',
#        'Chess', 'Team sports (soccer, football)',
#        'Individual sports (golf, running)', 'Volunteering', 'Meditation',
#        'Family', 'Reading', 'Gardening', 'Dance', 'Culture', 'Politics',
#        'Working out', 'Travel', 'Religion', 'Music', 'Pets',
#        'Extreme sports (sky diving)', 'Wine tasting', 'Shopping/fashion',
#        'Social networking', 'Art'],
#       dtype='object')

# %%
df_strengths_mentee_final.columns
# Out:
# Index(['Time management', 'Team building', 'Influencing', 'Negotiating',
#        'Creativity / innovation', 'Technical knowledge', 'Productivity',
#        'Design thinking', 'Cross-architecture', 'Competitive strategy',
#        'Effective listening', 'Prioritization', 'Coaching', 'Recognition',
#        'Communications (public speaking)', 'Empowerment', 'Finance',
#        'Change management', 'Customer interaction', 'Providing feedback',
#        'Personal Brand', 'Work / Life balance', 'Crucial conversations',
#        'Transition career path', 'Delegating', 'Story telling',
#        'Decision making', 'Critical thinking', 'Social Media',
#        'Accountability', 'Goal setting', 'Collaboration'],
#       dtype='object')

# %%
# same columns
for cols in df_onehot_mentee.columns:
    if cols not in df_onehot_mentor.columns:
        print(cols)

# %%
for cols in df_onehot_mentor.columns:
    if cols not in df_onehot_mentee.columns:
        print(cols)

# %% [markdown]
# # Calculating Similarity of Users

# %%
import scipy.spatial

ary = scipy.spatial.distance.cdist(df_onehot_mentor.iloc[:,1:], df_onehot_mentee.iloc[:,1:], metric='jaccard')

people_similarity = pd.DataFrame(ary, columns=df_onehot_mentee.index.values, index=df_onehot_mentor.index.values)
people_similarity
# Out:
#                          Ana Tojeiro  Yosephine Gita Asaria Hutauruk  \
# Luc Janssen                 0.842105                        0.857143
# Mary Catherine Dolehide     0.764706                        0.789474
# Leonora Steger              0.900000                        0.800000
# Steve Fuchs                 0.823529                        0.842105
# Chase Abrams                0.833333                        0.647059
# ...                              ...                             ...
# Andrew Bernath              0.777778                        0.736842
# Armando Perez               0.777778                        0.857143
# Denis Kodentsev             0.760000                        0.625000
# Octavian Preda              0.944444                        0.764706
# Glen Trible                 0.900000                        0.736842
#
#                          Nikolaos Papadopoulos  Lucia Caiata  Radhika Paliwal  \
# Luc Janssen                           0.850000      0.800000         0.750000
# Mary Catherine Dolehide               0.777778      0.850000         0.642857
# Leonora Steger                        0.722222      0.857143         0.750000
# Steve Fuchs                           0.894737      0.900000         0.714286
# Chase Abrams                          0.777778      0.789474         0.642857
# ...                                        ...           ...              ...
# Andrew Bernath                        0.789474      0.909091         0.666667
# Armando Perez                         0.850000      0.909091         0.571429
# Denis Kodentsev                       0.769231      0.821429         0.739130
# Octavian Preda                        0.888889      0.950000         0.785714
# Glen Trible                           0.722222      0.909091         0.750000
#
#                          Gabriele Antonio Innocenti  Basel Iskandarani  \
# Luc Janssen                                0.882353           0.647059
# Mary Catherine Dolehide                    0.800000           0.533333
# Leonora Steger                             0.882353           0.647059
# Steve Fuchs                                0.785714           0.764706
# Chase Abrams                               0.875000           0.705882
# ...                                             ...                ...
# Andrew Bernath                             0.812500           0.466667
# Armando Perez                              0.733333           0.562500
# Denis Kodentsev                            0.727273           0.666667
# Octavian Preda                             0.769231           0.823529
# Glen Trible                                0.882353           0.647059
#
#                          Eva Roussou  Gurmeet Johal  Felix Neulinger  ...  \
# Luc Janssen                 0.814815       0.692308         0.750000  ...
# Mary Catherine Dolehide     0.851852       0.777778         0.642857  ...
# Leonora Steger              0.857143       0.785714         0.666667  ...
# Steve Fuchs                 0.888889       0.814815         0.714286  ...
# Chase Abrams                0.807692       0.777778         0.642857  ...
# ...                              ...            ...              ...  ...
# Andrew Bernath              0.769231       0.740741         0.666667  ...
# Armando Perez               0.769231       0.740741         0.666667  ...
# Denis Kodentsev             0.677419       0.696970         0.681818  ...
# Octavian Preda              0.840000       0.851852         0.866667  ...
# Glen Trible                 0.857143       0.785714         0.750000  ...
#
#                          Jennifer Goehler  Rami Alfadel  J. Hunter Roman  \
# Luc Janssen                      0.812500      0.875000         0.875000
# Mary Catherine Dolehide          0.714286      0.866667         0.785714
# Leonora Steger                   0.812500      0.875000         0.875000
# Steve Fuchs                      0.692308      0.769231         0.857143
# Chase Abrams                     0.800000      0.866667         0.866667
# ...                                   ...           ...              ...
# Andrew Bernath                   0.733333      0.714286         0.500000
# Armando Perez                    0.733333      0.875000         0.800000
# Denis Kodentsev                  0.600000      0.826087         0.772727
# Octavian Preda                   0.933333      0.928571         0.750000
# Glen Trible                      0.812500      0.714286         0.800000
#
#                          Jara Osterfeld  Grady Evans  Alma Sejdovic  \
# Luc Janssen                    0.800000     0.666667       0.714286
# Mary Catherine Dolehide        0.785714     0.642857       0.692308
# Leonora Steger                 0.875000     0.571429       0.714286
# Steve Fuchs                    0.857143     0.615385       0.666667
# Chase Abrams                   0.866667     0.733333       0.785714
# ...                                 ...          ...            ...
# Andrew Bernath                 0.800000     0.461538       0.714286
# Armando Perez                  0.714286     0.666667       0.615385
# Denis Kodentsev                0.875000     0.739130       0.714286
# Octavian Preda                 0.928571     0.866667       0.636364
# Glen Trible                    0.800000     0.333333       0.800000
#
#                          Jacob Honore  Alberto Muinos Olego  Josef Kandelan  \
# Luc Janssen                  0.733333              0.791667        0.777778
# Mary Catherine Dolehide      0.615385              0.727273        0.814815
# Leonora Steger               0.642857              0.681818        0.730769
# Steve Fuchs                  0.785714              0.714286        0.851852
# Chase Abrams                 0.714286              0.727273        0.769231
# ...                               ...                   ...             ...
# Andrew Bernath               0.642857              0.681818        0.777778
# Armando Perez                0.733333              0.739130        0.777778
# Denis Kodentsev              0.782609              0.642857        0.600000
# Octavian Preda               0.857143              0.818182        0.846154
# Glen Trible                  0.642857              0.681818        0.821429
#
#                          Marie-Morgane Kergrohenn
# Luc Janssen                              0.714286
# Mary Catherine Dolehide                  0.866667
# Leonora Steger                           0.800000
# Steve Fuchs                              0.857143
# Chase Abrams                             0.866667
# ...                                           ...
# Andrew Bernath                           0.875000
# Armando Perez                            0.800000
# Denis Kodentsev                          0.714286
# Octavian Preda                           0.928571
# Glen Trible                              0.875000
#
# [89 rows x 59 columns]

# %%
a, b = people_similarity.stack().idxmin()
print(people_similarity.loc[[a], [b]])
# Out:
#                        Basel Iskandarani
# Mumtaz Bee Abdul Rauf           0.307692

# %% [markdown]
# # Assigning Mentor - Mentee

# %%
def create_cluster(df):
    clusters = {}
    for mentee in df.columns:
        mentee_cluster = df[mentee].nsmallest(len(df))
        data = {mentee : list(mentee_cluster.index)}
        clusters.update(data)
    return clusters

# %%
people_cluster = create_cluster(people_similarity)

# %%
"Martin Schubert" in people_cluster.values()
# Out:
# False

# %%
# people_similarity.sort_values("Ana Tojeiro", ascending=True)

# %% [markdown]
# # Consider mentee/mentor preferences
# We now have a ranking of the mentors that are most similar to the respective mentees. Each mentee has a list of the mentors ranked by their similarity regarding the survey choices.
#
# Now we consider special preferences that the mentees/mentors chose within the survey.
#
# The order of priorities considered is as following:
#
# 1. First preference of mentee
# 2. Theatre preference of mentor
# 3. Role preference of mentor
# 4. Mentor/Mentee in mind

# %%
def test_assignment():
    for mentee in people_cluster:
        if len(people_cluster[mentee]) < 1:
            raise ValueError(mentee, "has less than 1 mentor assigned!")
    print("Test passed.")

# %% [markdown]
# # 1. Prepare Data: Theatre
#
# ## 1.1. Mentor: Theatre

# %%
df_mentor_theatre = df_mentor_raw[["Would you prefer a mentee in the same theatre?", 
                                "Your theatre?"]]
                                #"Your segment?",
                                #"Would you prefer a mentee in a:", #sales or technical role
                                #"Would you prefer a mentee of the same gender?"]]

# filter by all the mentors that want a mentee in the same theatre
df_mentor_theatre_filter = df_mentor_theatre[df_mentor_theatre["Would you prefer a mentee in the same theatre?"]!="No preference"]

# %% [markdown]
# ## 2.2. Mentee: Theatre

# %%
df_mentee_theatre = df_mentee_raw[["If possible, would you prefer a mentor in the same theatre?", 
                                   "Your theatre?"]]
df_mentee_theatre_filter = df_mentee_theatre[df_mentee_theatre["If possible, would you prefer a mentor in the same theatre?"]!="No preference"]

# %% [markdown]
# # 2. Prepare Data: Role
# ## 2.1. Mentor: Role

# %%
df_mentor_role = df_mentor_raw[["Would you prefer a mentee in a:", 
                                "What is your title?"]]

# filter by all the mentors that want a mentee in the same theatre
df_mentor_role_filter = df_mentor_role[df_mentor_role["Would you prefer a mentee in a:"]!="No preference"]

# %%
def replace_roles(df, col):
    technical = ["technical", "system", "se", "Technichal",
                 "Justin Flateau"] # systems atchitect
    sales = ["account manager", "business development", "client", "sales specialist", "financial", "partner", 
             "regional director", "sales manager", "renewal", "business solutions", "regional manager", "cx",
             "bdm", "product specialist", "Collaboration Executive", "Account Specialist", "vsam", "vpam",
             "Joyce Huan Wang", # global AM
             "Susuk-Bujang", # AM
             "Missus Kergrohenn Marie-Morgane "] #vsam
    for person in df.index:
        person_role = (df[col].loc[person]).lower()
        if person == "Toby Rees":
            df[col][person] = "Technical role"
        if person == "Mark Sibuns":
            df[col][person] = "Sales role"
        if person == "Deepti Babber":
            df[col][person] = "Technical role"

        for tech_role in technical:
            if tech_role.lower() in person_role:
                df[col][person] = "Technical role"
        for sales_role in sales:
            if sales_role.lower() in person_role:
                df[col][person] = "Sales role"

# %%
replace_roles(df_mentor_role, "What is your title?")

# %%
def test_roles(df, col):
    if len(set(df[col])) > 2:
        raise ValueError("Error! Roles other than Sales & Technical Role present in dataset.")
    else:
        print("Test passed.")

# %%
test_roles(df_mentor_role, "What is your title?")
# Out:
# Test passed.

# %% [markdown]
# ## 2.2. Mentee: Role

# %%
df_mentee_role = df_mentee_raw[["If possible, would you prefer a mentor in a:", 
                                "What is your title?"]]
df_mentee_role_filter = df_mentee_role[df_mentee_role["If possible, would you prefer a mentor in a:"]!="No preference"]

# %%
replace_roles(df_mentee_role, "What is your title?")

# %%
set(df_mentee_role["What is your title?"])
# Out:
# {'Sales role', 'Technical role'}

# %%
test_roles(df_mentee_role, "What is your title?")
# Out:
# Test passed.

# %% [markdown]
# # 3. Prepare Data: Segment
# ## 3.1. Mentor: Segment

# %%
df_mentor_segment = df_mentor_raw[["Your segment?"]]
df_mentee_segment_filter = df_mentee_role[df_mentee_role["If possible, would you prefer a mentor in a:"]!="No preference"]

for person in df_mentor_segment.index:
    if df_mentor_segment["Your segment?"][person] == "Enterprise Networking":
        df_mentor_segment["Your segment?"][person] = "Ent. Networking"

# %%
set(df_mentor_segment["Your segment?"])
# Out:
# {' Enterprise, commercial, public sector',
#  'AppDynamics',
#  'CGEM',
#  'CGEM Enterprise',
#  'CGEM Premier Global accounts',
#  'CX',
#  'Commercial',
#  'Defence',
#  'Ent. Networking',
#  'Enterprise',
#  'FED',
#  'GES/CX',
#  'GVSE',
#  'GVSS',
#  'Global Specialist Organization ',
#  'Global Specialists Org',
#  'Partner',
#  'Public Sector',
#  'Public Sector (Local and State Gov)',
#  'Public Service',
#  'Public sector',
#  'SLED',
#  'Service Provider',
#  'Specialist, AppDynamics'}

# %% [markdown]
# ## 3.2. Mentee: Segment

# %%
col = "If possible, which segment would you like your mentor to be from?"
df_mentee_segment = df_mentee_raw[[col]]
df_mentee_segment_filter = df_mentee_segment[df_mentee_segment[col]!="No preference"]
df_mentee_segment_filter = df_mentee_segment_filter[df_mentee_segment_filter[col]!="No Preference"]
df_mentee_segment_filter = df_mentee_segment_filter[df_mentee_segment_filter[col]!="Any"]
df_mentee_segment_filter = df_mentee_segment_filter[df_mentee_segment_filter[col]!="Enterprise, SP, Commercial, SLED, FED all work  "]

# %%
set(df_mentee_segment_filter["If possible, which segment would you like your mentor to be from?"])
# Out:
# {'Commercial',
#  'Enterprise',
#  'FED',
#  'I still need to learn the above segments',
#  'Partner',
#  'SLED',
#  'SP or CX',
#  'Service Provider',
#  'worked in multiple segments before'}

# %% [markdown]
# # 4. Filter by: First Preference of Mentee

# %%
# prepare dataset
df_mentee_prio = df_mentee_raw[["If possible, what's your first priority in matching you with a mentor?"]]
df_mentee_prio = df_mentee_prio[df_mentee_prio["If possible, what's your first priority in matching you with a mentor?"]!="No preference"]
df_mentee_prio = df_mentee_prio[df_mentee_prio["If possible, what's your first priority in matching you with a mentor?"]!="Strengths you seek to develop"]
df_mentee_prio = df_mentee_prio[df_mentee_prio["If possible, what's your first priority in matching you with a mentor?"]!="Personal interests"]

# %%
def filter_by_pref(mentee, filter_by):
    if filter_by == "Theatre":
        mentee_theatre = df_mentee_theatre["Your theatre?"].loc[mentee]
        for mentor in df_mentor_theatre.index:
            mentor_theatre = df_mentor_theatre["Your theatre?"].loc[mentor] 
            if mentee_theatre != mentor_theatre:
                try:
                    people_cluster[mentee].remove(mentor)
                except:
                    continue
    elif filter_by == "Role":
        mentee_role = df_mentee_role["What is your title?"].loc[mentee]
        for mentor in df_mentor_role.index:
            mentor_role = df_mentor_role["What is your title?"].loc[mentor]
            if mentee_role != mentor_role:
                try:
                    people_cluster[mentee].remove(mentor)
                except:
                    continue
    elif filter_by == "Segment":
        if mentee in df_mentee_segment_filter.index:
            mentee_segment = df_mentee_segment_filter["If possible, which segment would you like your mentor to be from?"].loc[mentee]
            for mentor in df_mentor_segment.index:
                mentor_segment = df_mentor_segment["Your segment?"].loc[mentor]
                if mentee_segment.lower() not in mentor_segment.lower():
                    try:
                        people_cluster[mentee].remove(mentor)
                    except:
                        continue
    elif filter_by == "Gender":
        mentee_gender = df_mentee_raw["Gender"].loc[mentee]
        for mentor in df_mentor_raw.index:
            mentor_gender = df_mentor_raw["Gender"].loc[mentor]
            if mentee_gender != mentor_gender:
                try:
                    people_cluster[mentee].remove(mentor)
                except:
                    continue

# %%
col ="If possible, what's your first priority in matching you with a mentor?"
for mentee in df_mentee_prio.index:
    if df_mentee_prio[col].loc[mentee] == "Theatre":
        filter_by_pref(mentee, "Theatre")
    elif df_mentee_prio[col].loc[mentee] == "Role (Tech/Sales)":
        filter_by_pref(mentee, "Role")
    elif df_mentee_prio[col].loc[mentee] == "Segment":
        filter_by_pref(mentee, "Segment")
    elif df_mentee_prio[col].loc[mentee] == "Gender":
        filter_by_pref(mentee, "Gender")

# %%
test_assignment()
# Out:
# Test passed.

# %%
df_mentee_raw.isnull().sum(axis = 0)
# Out:
# ID                                                                          0
# Start time                                                                  0
# Completion time                                                             0
# Email                                                                       0
# Gender                                                                      0
# What is your title?                                                         0
# Your city of residence                                                      0
# Your country of residence                                                   0
# Your theatre?                                                               0
# Your linkedIn profile link                                                  0
# Your CSAP track                                                             0
# What are your early expectations from this mentoring engagement?            0
# What are the qualities you look for in a good mentor?                       1
# What qualifies you to be a good mentee?                                     1
# What are you most likely to want out of this mentoring engagement?          0
# What are the strengths you'd like to further develop?                       0
# What are your personal interests?                                           0
# If possible, would you prefer a mentor in the same theatre?                 0
# If possible, would you prefer a mentor of the same gender?                  0
# If possible, would you prefer a mentor in a:                                0
# If possible, which segment would you like your mentor to be from?           0
# If possible, what's your first priority in matching you with a mentor?      0
# If possible, what's your second priority in matching you with a mentor?     0
# Any final comments or suggestions before you submit?                       34
# dtype: int64

# %% [markdown]
# # 5. Filter by: Mentee/mentor in Mind

# %%
df_mentor_inmind = pd.DataFrame(df_mentor_raw["Let us know if you already have a CSAP mentee in mind"])

# %%
df_mentor_inmind = df_mentor_inmind[df_mentor_inmind['Let us know if you already have a CSAP mentee in mind'].notna()]

# %%
df_mentor_inmind
# Out:
#                       Let us know if you already have a CSAP mentee in mind
# Name
# Joyce Huan Wang                                            I don't have.
# Ron Bogman                                                             -
# Vincent Jansen                                                       no
# Primpreawpan Wangsiri                                               none
# Martin Schubert                                          Florian Herkert
# Christina Mackes                                                     No
# Joost van Heezik       Vincent Vermeer, based on feedback from Toine ...
# TAE GUL Lee                                               Hwa Seok Seon
# Pawan Kumar M                                                       Nope
# Ray Torres                                          no one in particular
# Scott Teagarden                                         Zachary Seinfeld
# Keith Harmon           I currently have commitments to Leah Markward ...

# %%
pairs = {}
for mentee in df_mentee_raw.index:
    if mentee in list(df_mentor_inmind["Let us know if you already have a CSAP mentee in mind"]):
        mentor = df_mentor_inmind.index[df_mentor_inmind["Let us know if you already have a CSAP mentee in mind"] == mentee]
        print("Match:" , mentor[0] , "and" , mentee)
        pairs[mentee] = mentor[0]
# Out:
# Match: Martin Schubert and Florian Herkert

# %% [markdown]
# Replace the metee in mind in the people cluster distionary:

# %%
# remove the mentors from all mentees
mentors = list(people_cluster.values())
for mentee in pairs:
    for mentor in mentors:
        try:
            mentor.remove(pairs[mentee])
        except:
            continue
    # add mentor to respective mentee
    people_cluster[mentee].insert(0, pairs[mentee])

# %%
test_assignment()
# Out:
# Test passed.

# %%
# test if only the mentee in pairs has the mentor in pairs assigned
def test_mentor_mind():
    for mentee in people_cluster:
        for mentor in people_cluster[mentee]:
            if mentor in pairs.values():
                if mentee not in pairs.keys():
                    print("Error for mentee:", mentee, "and mentor:", mentor)
    print("Test passed.")

# %%
test_mentor_mind()
# Out:
# Test passed.

# %% [markdown]
# # 6. Filter: Make Order Unique

# %%
people_cluster_unique = {}
for mentee in people_cluster.keys():
    people_cluster_unique[mentee] = people_cluster[mentee][0:10]

# %%
def sort_unique(cluster, max_rounds=20):
    i = 0
    j = 1
    count = []
    for number in range(0,max_rounds):
        count.append(0)
    rounds = 0
    mentees = list(cluster.keys())
    while rounds < max_rounds:
        while i < len(cluster):
            while j < len(cluster):
                to_compare = list(zip(cluster[mentees[i]], cluster[mentees[j]]))[0]
                if to_compare[0] == to_compare[1]:
                    count[rounds] += 1
                    if rounds != 0:
                        if count[rounds] >= count[rounds-1]:
                            random_position = random.randint(0, 1)
                            if random_position == 0:
                                cluster[mentees[j]][0], cluster[mentees[j]][1] = cluster[mentees[j]][1], cluster[mentees[j]][0]
                            else:
                                cluster[mentees[i]][0], cluster[mentees[i]][1] = cluster[mentees[i]][1], cluster[mentees[i]][0]
                        else:
                            random_position = random.randint(0, 1)
                            if random_position == 0:
                                cluster[mentees[j]][0], cluster[mentees[j]][2] = cluster[mentees[j]][2], cluster[mentees[j]][0]
                            else:
                                cluster[mentees[i]][0], cluster[mentees[i]][2] = cluster[mentees[i]][2], cluster[mentees[i]][0] 
                    else:
                        random_position = random.randint(0, 1)
                        if random_position == 0:
                            cluster[mentees[j]][0], cluster[mentees[j]][1] = cluster[mentees[j]][1], cluster[mentees[j]][0]
                        else:
                            cluster[mentees[i]][0], cluster[mentees[i]][1] = cluster[mentees[i]][1], cluster[mentees[i]][0]                
                j+=1
            i += 1
            j = i+1
        print("Completed round:", rounds, "with count:", count[rounds])
        if count[rounds] > 0:
            if rounds == max_rounds:
                print("##### Error ##### Could not converge up to round:", rounds, "with count:", count[rounds])
            else:
                rounds += 1
                i = 0
                j = 1
        else:
            print("\nSucces! Converged at round:", rounds)
            break

# %%
sort_unique(people_cluster_unique)
# Out:
# Completed round: 0 with count: 1
# Completed round: 1 with count: 0
#
# Succes! Converged at round: 1

# %% [markdown]
# # 7. Export results to Excel Sheet

# %%
# Create an new Excel file and add a worksheet.
workbook = xlsxwriter.Workbook('people_matching_final.xlsx')
worksheet = workbook.add_worksheet()

# format the sheet
worksheet.set_column('A:A', 30)
worksheet.set_column('B:K', 20)
# mentee cell (0,0)
mentee_cell = workbook.add_format({'bold': True})
mentee_cell.set_right()
mentee_cell.set_bottom()
# vertical
vertical = workbook.add_format({'bold': True})
vertical.set_right()
# horzontal
horizontal = workbook.add_format({'bold': True})
horizontal.set_bottom()

# Write "Mentee" cell
worksheet.write(0, 0, "Mentee", mentee_cell)


# Write mentee names
i = 1
for mentee in people_cluster_unique:
    worksheet.write(i, 0, str(mentee), vertical)
    i+=1

# Write ranks
i = 1
for j in range(0,10):
    worksheet.write(0, i, str("Rank " + str(i)), horizontal)
    i+=1

# Write mentor names
row = 1
for mentee in people_cluster_unique:
    mentors = people_cluster_unique[mentee]
    col = 1
    for mentor in mentors:
        worksheet.write(row, col, mentor)
        col+=1
    row +=1
    
workbook.close()

# %% [markdown]
# # 8. Test results

# %%
# function that tests whether a mentee has a mentor on rank 1 that is his most similar mentor
def rank_test():
    error_count = 0
    not_nr1_count = 0
    for mentee in people_similarity.columns:
        mentors_similar = list(people_similarity[mentee].nsmallest().index)
        mentors_assigned = people_cluster[mentee]
        for top_mentors in mentors_similar:
            if top_mentors not in mentors_similar:
                error_count += 1
        if error_count != 0:
            raise ValueError("Error! Mentee", mentee, "has not all of its top 5 mentors in the final ranking.")
        if mentors_similar[0] != mentors_assigned[0]:
            not_nr1_count += 1
    print("Test passed.")
    print(not_nr1_count, "/", len(people_similarity.columns), "do not have mentor nr1 on rank1.")

# %%
rank_test()
# Out:
# Test passed.
# 23 / 59 do not have mentor nr1 on rank1.

# %%
mentors_similar = list(people_similarity["Diyar Alyasiri"].nsmallest())
mentors_similar
# Out:
# [0.7142857142857143,
#  0.7142857142857143,
#  0.7142857142857143,
#  0.7142857142857143,
#  0.7142857142857143]

# %%
for mentee in people_similarity.columns:
    print(mentee, "-", (list(people_similarity[mentee].nsmallest().index))[0] , "-",
         (list(people_similarity[mentee].nsmallest()))[0])
# Out:
# Ana Tojeiro - Tijana Pejnovic - 0.7058823529411765
# Yosephine Gita Asaria Hutauruk - Chris Miles - 0.5
# Nikolaos Papadopoulos - Ron Bogman - 0.6470588235294118
# Lucia Caiata - Konstantin Koytchev - 0.6666666666666666
# Radhika Paliwal - Russ Doherty - 0.5384615384615384
# Gabriele Antonio Innocenti - Joost van Heezik - 0.6153846153846154
# Basel Iskandarani - Mumtaz Bee Abdul Rauf - 0.3076923076923077
# Eva Roussou - Sandeep Yadav - 0.6
# Gurmeet Johal - Joseph McIntyre - 0.5641025641025641
# Felix Neulinger - Konstantin Koytchev - 0.5714285714285714
# Tony Lenssens - Joost van Heezik - 0.5833333333333334
# Laurene Courreges - Tijana Pejnovic - 0.631578947368421
# Cameron Chestnut - Andrew Bernath - 0.36363636363636365
# Rhiona Pikeur - Mary Catherine Dolehide - 0.5833333333333334
# Diyar Alyasiri - John Vigil - 0.7142857142857143
# Alex Hoecht - Kevin Armstrong - 0.6428571428571429
# Francesco Carmine Carbone - Niek van Geffen - 0.6153846153846154
# Chiara Pannacci - David Medeiro Danielsen - 0.6666666666666666
# Peter Morris - Timo Baumeister - 0.6923076923076923
# Sierra Tokanel - Anthony Marabella - 0.6153846153846154
# Brian O'Sullivan - Anthony Marabella - 0.5
# Maria Camila Marin - Keith Harmon - 0.6153846153846154
# Eda Akturk - Gabby McGee - 0.6153846153846154
# Nish Solanki - Eric Sherwood - 0.5714285714285714
# Andrew LaBrie - Rotsen Bulan - 0.6086956521739131
# Yara Shams El Din - Gabby McGee - 0.6153846153846154
# Ryan Greenwood - John Vigil - 0.5714285714285714
# Flora Shi - Mikhail Safronov - 0.5
# Mathias Cronjager - Glen Trible - 0.6923076923076923
# Paige Patterson - Terry Robinson - 0.6923076923076923
# Seda Gulbahar - Dina Syntila - 0.6428571428571429
# Nico Hoffmann - Chris Colwell - 0.6153846153846154
# Florian Herkert - Octavian Preda - 0.5
# Daniel Dabrowski - Susan MacDonald - 0.6153846153846154
# Max Amato - Terry Robinson - 0.36363636363636365
# Anne Madariaga - Sandeep Yadav - 0.5769230769230769
# Jennifer Seo - Russ Doherty - 0.5384615384615384
# Deepti Babber - Gibby Bates - 0.6153846153846154
# Josh Ingeniero - Armando Perez - 0.6153846153846154
# Maria Garcia Maresca - Daniela Hernandez - 0.6428571428571429
# Camillo Dall'Oglio - Kevin Jones - 0.6923076923076923
# Gaia Bergamaschi - Niek van Geffen - 0.6666666666666666
# Jamie Watts - Eric Sherwood - 0.6666666666666666
# Alvin Lau - Bob Swain - 0.5714285714285714
# Andre Winkfield - Konstantin Koytchev - 0.6153846153846154
# Timi Omoyajowo - Mark Sibuns - 0.6470588235294118
# Iaroslav Bondarenko - Kevin Jones - 0.5454545454545454
# Nicola Chiarappa - Konstantin Koytchev - 0.7142857142857143
# Wu Ziyu - Terry Robinson - 0.5
# Jennifer Goehler - Denis Kodentsev - 0.6
# Rami Alfadel - Kathy Saye - 0.6923076923076923
# J. Hunter Roman - Andrew Bernath - 0.5
# Jara Osterfeld - Adriano Alves - 0.6428571428571429
# Grady Evans - Chris Miles - 0.3333333333333333
# Alma Sejdovic - Tijana Pejnovic - 0.5
# Jacob Honore - Timo Baumeister - 0.5
# Alberto Muinos Olego - John Vigil - 0.55
# Josef Kandelan - Joseph McIntyre - 0.4722222222222222
# Marie-Morgane Kergrohenn - Kathy Saye - 0.6923076923076923

# %% [markdown]
# # Testzone

# %%
import matplotlib.pyplot as plt

def compare_people(mentor, mentee, compare="all", count_sims="no"):  
    fig = plt.figure()
    ax = fig.add_axes([0,0,1,1])
    if compare == "want" or compare == "give":
        langs = list(df_want_mentee_final.columns)
        data_mentee = list(df_want_mentee_final.loc[mentee, : ])
        data_mentor = list(df_give_mentor_final.loc[mentor, : ])
    elif compare == "strengths":
        langs = list(df_strengths_mentee_final.columns)
        data_mentee = list(df_strengths_mentee_final.loc[mentee, : ])
        data_mentor = list(df_strengths_mentor_final.loc[mentor, : ])
    elif compare == "interests":
        langs = list(df_interests_mentee_final.columns)
        data_mentee = list(df_interests_mentee_final.loc[mentee, : ])
        data_mentor = list(df_interests_mentor_final.loc[mentor, : ])   
    else:
        langs = list(df_onehot_mentee.columns)
        data_mentee = list(df_onehot_mentee.loc[mentee, : ])
        data_mentor = list(df_onehot_mentor.loc[mentor, : ])
    if count_sims != "no":
        count = sum(1 for i, j in zip(data_mentee, data_mentor) if i == j)
        print(str(count) + "/" + str(len(data_mentee)))
    plt.plot(langs, data_mentee)
    plt.plot(langs, data_mentor)
    

compare_people("Sandrine Henry", "Lucia Caiata", count_sims="yes")
#ax.bar(langs, data)
plt.show()
# Out:
# 46/62

# %%
compare_people("Octavian Preda", "Ana Tojeiro", count_sims="yes")
# Out:
# 45/62

# %%
x = list(df_strengths_mentee_final.columns)
x.sort()
x
# Out:
# ['Accountability',
#  'Change management',
#  'Coaching',
#  'Collaboration',
#  'Communications (public speaking)',
#  'Competitive strategy',
#  'Creativity / innovation',
#  'Critical thinking',
#  'Cross-architecture',
#  'Crucial conversations',
#  'Customer interaction',
#  'Decision making',
#  'Delegating',
#  'Design thinking',
#  'Effective listening',
#  'Empowerment',
#  'Finance',
#  'Goal setting',
#  'Influencing',
#  'Negotiating',
#  'Personal Brand',
#  'Prioritization',
#  'Productivity',
#  'Providing feedback',
#  'Recognition',
#  'Social Media',
#  'Story telling',
#  'Team building',
#  'Technical knowledge',
#  'Time management',
#  'Transition career path',
#  'Work / Life balance']

# %%
x = list(df_strengths_mentor_final.columns)
x.sort()
x
# Out:
# ['Accountability',
#  'Change management',
#  'Coaching',
#  'Collaboration',
#  'Communications (public speaking)',
#  'Competitive strategy',
#  'Creativity / innovation',
#  'Critical thinking',
#  'Cross-architecture',
#  'Crucial conversations',
#  'Customer interaction',
#  'Decision making',
#  'Delegating',
#  'Design thinking',
#  'Effective listening',
#  'Empowerment',
#  'Finance',
#  'Goal setting',
#  'Influencing',
#  'Negotiating',
#  'Personal Brand',
#  'Prioritization',
#  'Productivity',
#  'Providing feedback',
#  'Recognition',
#  'Social Media',
#  'Story telling',
#  'Team building',
#  'Technical knowledge',
#  'Time management',
#  'Transition career path',
#  'Work / Life balance']

# %%
df_onehot_mentee
# Out:
#                                 Accountability  Art  Change management  Chess  \
# Name
# Ana Tojeiro                                  0    0                  0      0
# Yosephine Gita Asaria Hutauruk               0    1                  0      0
# Nikolaos Papadopoulos                        0    0                  0      0
# Lucia Caiata                                 0    0                  0      0
# Radhika Paliwal                              0    1                  0      0
# Gabriele Antonio Innocenti                   0    0                  0      0
# Basel Iskandarani                            0    0                  1      0
# Eva Roussou                                  0    0                  0      0
# Gurmeet Johal                                0    0                  0      0
# Felix Neulinger                              0    0                  0      1
# Tony Lenssens                                0    0                  0      0
# Laurene Courreges                            0    1                  0      0
# Cameron Chestnut                             0    0                  0      0
# Rhiona Pikeur                                0    0                  0      0
# Diyar Alyasiri                               0    0                  0      0
# Alex Hoecht                                  0    0                  0      0
# Francesco Carmine Carbone                    0    0                  0      0
# Chiara Pannacci                              0    0                  0      0
# Peter Morris                                 0    1                  0      0
# Sierra Tokanel                               0    0                  1      0
# Brian O'Sullivan                             0    0                  0      0
# Maria Camila Marin                           0    0                  0      0
# Eda Akturk                                   0    0                  0      0
# Nish Solanki                                 0    0                  0      0
# Andrew LaBrie                                0    0                  0      0
# Yara Shams El Din                            0    0                  0      0
# Ryan Greenwood                               0    0                  0      0
# Flora Shi                                    0    0                  0      0
# Mathias Cronjager                            0    0                  0      0
# Paige Patterson                              0    0                  0      0
# Seda Gulbahar                                0    0                  0      0
# Nico Hoffmann                                0    0                  0      0
# Florian Herkert                              0    0                  0      0
# Daniel Dabrowski                             0    1                  1      0
# Max Amato                                    0    0                  0      0
# Anne Madariaga                               1    0                  0      0
# Jennifer Seo                                 0    0                  0      0
# Deepti Babber                                0    0                  0      0
# Josh Ingeniero                               0    0                  0      0
# Maria Garcia Maresca                         0    1                  0      0
# Camillo Dall'Oglio                           0    0                  0      0
# Gaia Bergamaschi                             0    0                  0      0
# Jamie Watts                                  0    0                  0      0
# Alvin Lau                                    0    0                  0      0
# Andre Winkfield                              0    1                  0      0
# Timi Omoyajowo                               0    0                  0      0
# Iaroslav Bondarenko                          0    0                  0      0
# Nicola Chiarappa                             0    0                  0      0
# Wu Ziyu                                      0    0                  0      0
# Jennifer Goehler                             0    0                  0      0
# Rami Alfadel                                 0    0                  0      0
# J. Hunter Roman                              0    0                  0      0
# Jara Osterfeld                               0    0                  1      0
# Grady Evans                                  0    0                  0      0
# Alma Sejdovic                                1    0                  0      0
# Jacob Honore                                 0    0                  0      0
# Alberto Muinos Olego                         0    0                  0      0
# Josef Kandelan                               0    0                  1      0
# Marie-Morgane Kergrohenn                     0    0                  0      0
#
#                                 Coaching  Collaboration  \
# Name
# Ana Tojeiro                            0              0
# Yosephine Gita Asaria Hutauruk         0              0
# Nikolaos Papadopoulos                  0              0
# Lucia Caiata                           0              0
# Radhika Paliwal                        0              0
# Gabriele Antonio Innocenti             0              0
# Basel Iskandarani                      0              0
# Eva Roussou                            0              0
# Gurmeet Johal                          0              0
# Felix Neulinger                        0              0
# Tony Lenssens                          0              0
# Laurene Courreges                      0              0
# Cameron Chestnut                       0              0
# Rhiona Pikeur                          0              0
# Diyar Alyasiri                         0              0
# Alex Hoecht                            0              0
# Francesco Carmine Carbone              0              0
# Chiara Pannacci                        0              0
# Peter Morris                           0              0
# Sierra Tokanel                         0              0
# Brian O'Sullivan                       0              0
# Maria Camila Marin                     0              0
# Eda Akturk                             0              0
# Nish Solanki                           0              0
# Andrew LaBrie                          0              0
# Yara Shams El Din                      0              0
# Ryan Greenwood                         0              0
# Flora Shi                              0              0
# Mathias Cronjager                      1              0
# Paige Patterson                        0              0
# Seda Gulbahar                          0              0
# Nico Hoffmann                          1              0
# Florian Herkert                        0              0
# Daniel Dabrowski                       0              0
# Max Amato                              0              0
# Anne Madariaga                         0              0
# Jennifer Seo                           0              1
# Deepti Babber                          0              0
# Josh Ingeniero                         0              0
# Maria Garcia Maresca                   0              0
# Camillo Dall'Oglio                     0              0
# Gaia Bergamaschi                       0              0
# Jamie Watts                            0              0
# Alvin Lau                              0              0
# Andre Winkfield                        0              0
# Timi Omoyajowo                         0              0
# Iaroslav Bondarenko                    0              0
# Nicola Chiarappa                       0              0
# Wu Ziyu                                0              0
# Jennifer Goehler                       0              0
# Rami Alfadel                           0              0
# J. Hunter Roman                        0              0
# Jara Osterfeld                         0              0
# Grady Evans                            1              0
# Alma Sejdovic                          0              0
# Jacob Honore                           0              0
# Alberto Muinos Olego                   1              0
# Josef Kandelan                         0              0
# Marie-Morgane Kergrohenn               0              0
#
#                                 Communications (public speaking)  \
# Name
# Ana Tojeiro                                                    0
# Yosephine Gita Asaria Hutauruk                                 0
# Nikolaos Papadopoulos                                          0
# Lucia Caiata                                                   0
# Radhika Paliwal                                                1
# Gabriele Antonio Innocenti                                     1
# Basel Iskandarani                                              0
# Eva Roussou                                                    1
# Gurmeet Johal                                                  1
# Felix Neulinger                                                0
# Tony Lenssens                                                  1
# Laurene Courreges                                              0
# Cameron Chestnut                                               0
# Rhiona Pikeur                                                  0
# Diyar Alyasiri                                                 1
# Alex Hoecht                                                    0
# Francesco Carmine Carbone                                      0
# Chiara Pannacci                                                0
# Peter Morris                                                   0
# Sierra Tokanel                                                 0
# Brian O'Sullivan                                               0
# Maria Camila Marin                                             0
# Eda Akturk                                                     0
# Nish Solanki                                                   0
# Andrew LaBrie                                                  0
# Yara Shams El Din                                              0
# Ryan Greenwood                                                 0
# Flora Shi                                                      0
# Mathias Cronjager                                              0
# Paige Patterson                                                0
# Seda Gulbahar                                                  1
# Nico Hoffmann                                                  0
# Florian Herkert                                                0
# Daniel Dabrowski                                               0
# Max Amato                                                      0
# Anne Madariaga                                                 1
# Jennifer Seo                                                   0
# Deepti Babber                                                  0
# Josh Ingeniero                                                 1
# Maria Garcia Maresca                                           0
# Camillo Dall'Oglio                                             0
# Gaia Bergamaschi                                               0
# Jamie Watts                                                    0
# Alvin Lau                                                      1
# Andre Winkfield                                                0
# Timi Omoyajowo                                                 1
# Iaroslav Bondarenko                                            1
# Nicola Chiarappa                                               0
# Wu Ziyu                                                        0
# Jennifer Goehler                                               1
# Rami Alfadel                                                   0
# J. Hunter Roman                                                0
# Jara Osterfeld                                                 0
# Grady Evans                                                    0
# Alma Sejdovic                                                  0
# Jacob Honore                                                   0
# Alberto Muinos Olego                                           0
# Josef Kandelan                                                 0
# Marie-Morgane Kergrohenn                                       1
#
#                                 Competitive strategy  Cooking  \
# Name
# Ana Tojeiro                                        0        0
# Yosephine Gita Asaria Hutauruk                     0        0
# Nikolaos Papadopoulos                              0        0
# Lucia Caiata                                       0        1
# Radhika Paliwal                                    0        0
# Gabriele Antonio Innocenti                         0        0
# Basel Iskandarani                                  1        0
# Eva Roussou                                        1        1
# Gurmeet Johal                                      1        0
# Felix Neulinger                                    0        0
# Tony Lenssens                                      0        0
# Laurene Courreges                                  0        1
# Cameron Chestnut                                   1        0
# Rhiona Pikeur                                      0        1
# Diyar Alyasiri                                     0        0
# Alex Hoecht                                        1        1
# Francesco Carmine Carbone                          0        0
# Chiara Pannacci                                    0        0
# Peter Morris                                       0        0
# Sierra Tokanel                                     0        1
# Brian O'Sullivan                                   0        1
# Maria Camila Marin                                 1        1
# Eda Akturk                                         1        0
# Nish Solanki                                       0        0
# Andrew LaBrie                                      0        1
# Yara Shams El Din                                  1        0
# Ryan Greenwood                                     0        0
# Flora Shi                                          0        0
# Mathias Cronjager                                  0        0
# Paige Patterson                                    1        0
# Seda Gulbahar                                      0        0
# Nico Hoffmann                                      0        0
# Florian Herkert                                    0        0
# Daniel Dabrowski                                   0        0
# Max Amato                                          1        0
# Anne Madariaga                                     1        0
# Jennifer Seo                                       0        0
# Deepti Babber                                      0        1
# Josh Ingeniero                                     0        0
# Maria Garcia Maresca                               0        0
# Camillo Dall'Oglio                                 0        0
# Gaia Bergamaschi                                   0        1
# Jamie Watts                                        0        1
# Alvin Lau                                          0        0
# Andre Winkfield                                    0        0
# Timi Omoyajowo                                     0        1
# Iaroslav Bondarenko                                1        0
# Nicola Chiarappa                                   0        0
# Wu Ziyu                                            1        0
# Jennifer Goehler                                   0        0
# Rami Alfadel                                       0        0
# J. Hunter Roman                                    1        0
# Jara Osterfeld                                     0        0
# Grady Evans                                        0        0
# Alma Sejdovic                                      0        0
# Jacob Honore                                       0        0
# Alberto Muinos Olego                               0        0
# Josef Kandelan                                     0        1
# Marie-Morgane Kergrohenn                           0        1
#
#                                 Creativity / innovation  ...  \
# Name                                                     ...
# Ana Tojeiro                                           0  ...
# Yosephine Gita Asaria Hutauruk                        1  ...
# Nikolaos Papadopoulos                                 1  ...
# Lucia Caiata                                          0  ...
# Radhika Paliwal                                       0  ...
# Gabriele Antonio Innocenti                            0  ...
# Basel Iskandarani                                     0  ...
# Eva Roussou                                           1  ...
# Gurmeet Johal                                         1  ...
# Felix Neulinger                                       0  ...
# Tony Lenssens                                         1  ...
# Laurene Courreges                                     0  ...
# Cameron Chestnut                                      0  ...
# Rhiona Pikeur                                         0  ...
# Diyar Alyasiri                                        0  ...
# Alex Hoecht                                           0  ...
# Francesco Carmine Carbone                             0  ...
# Chiara Pannacci                                       0  ...
# Peter Morris                                          0  ...
# Sierra Tokanel                                        0  ...
# Brian O'Sullivan                                      0  ...
# Maria Camila Marin                                    0  ...
# Eda Akturk                                            0  ...
# Nish Solanki                                          0  ...
# Andrew LaBrie                                         0  ...
# Yara Shams El Din                                     0  ...
# Ryan Greenwood                                        0  ...
# Flora Shi                                             0  ...
# Mathias Cronjager                                     0  ...
# Paige Patterson                                       1  ...
# Seda Gulbahar                                         0  ...
# Nico Hoffmann                                         0  ...
# Florian Herkert                                       0  ...
# Daniel Dabrowski                                      0  ...
# Max Amato                                             0  ...
# Anne Madariaga                                        1  ...
# Jennifer Seo                                          0  ...
# Deepti Babber                                         0  ...
# Josh Ingeniero                                        0  ...
# Maria Garcia Maresca                                  0  ...
# Camillo Dall'Oglio                                    0  ...
# Gaia Bergamaschi                                      0  ...
# Jamie Watts                                           0  ...
# Alvin Lau                                             0  ...
# Andre Winkfield                                       0  ...
# Timi Omoyajowo                                        0  ...
# Iaroslav Bondarenko                                   0  ...
# Nicola Chiarappa                                      0  ...
# Wu Ziyu                                               0  ...
# Jennifer Goehler                                      0  ...
# Rami Alfadel                                          1  ...
# J. Hunter Roman                                       0  ...
# Jara Osterfeld                                        0  ...
# Grady Evans                                           1  ...
# Alma Sejdovic                                         0  ...
# Jacob Honore                                          0  ...
# Alberto Muinos Olego                                  0  ...
# Josef Kandelan                                        0  ...
# Marie-Morgane Kergrohenn                              0  ...
#
#                                 Transition career path  Travel  Volunteering  \
# Name
# Ana Tojeiro                                          0       1             1
# Yosephine Gita Asaria Hutauruk                       0       0             0
# Nikolaos Papadopoulos                                0       0             0
# Lucia Caiata                                         1       0             0
# Radhika Paliwal                                      0       1             0
# Gabriele Antonio Innocenti                           0       1             0
# Basel Iskandarani                                    0       1             0
# Eva Roussou                                          1       1             0
# Gurmeet Johal                                        0       0             0
# Felix Neulinger                                      0       1             0
# Tony Lenssens                                        0       1             0
# Laurene Courreges                                    0       1             1
# Cameron Chestnut                                     0       0             0
# Rhiona Pikeur                                        0       1             0
# Diyar Alyasiri                                       0       0             0
# Alex Hoecht                                          0       0             0
# Francesco Carmine Carbone                            0       1             0
# Chiara Pannacci                                      0       1             0
# Peter Morris                                         1       0             0
# Sierra Tokanel                                       0       0             0
# Brian O'Sullivan                                     0       0             0
# Maria Camila Marin                                   1       1             0
# Eda Akturk                                           1       1             0
# Nish Solanki                                         1       1             0
# Andrew LaBrie                                        1       1             0
# Yara Shams El Din                                    0       1             0
# Ryan Greenwood                                       1       1             0
# Flora Shi                                            1       1             0
# Mathias Cronjager                                    0       0             0
# Paige Patterson                                      0       0             0
# Seda Gulbahar                                        0       0             1
# Nico Hoffmann                                        0       1             0
# Florian Herkert                                      0       1             0
# Daniel Dabrowski                                     0       0             0
# Max Amato                                            0       1             0
# Anne Madariaga                                       0       1             0
# Jennifer Seo                                         1       0             0
# Deepti Babber                                        1       1             1
# Josh Ingeniero                                       0       1             0
# Maria Garcia Maresca                                 1       1             0
# Camillo Dall'Oglio                                   0       0             0
# Gaia Bergamaschi                                     0       0             1
# Jamie Watts                                          1       0             0
# Alvin Lau                                            0       1             0
# Andre Winkfield                                      0       0             0
# Timi Omoyajowo                                       0       0             0
# Iaroslav Bondarenko                                  0       0             0
# Nicola Chiarappa                                     1       0             0
# Wu Ziyu                                              0       1             0
# Jennifer Goehler                                     0       1             0
# Rami Alfadel                                         0       0             0
# J. Hunter Roman                                      1       1             0
# Jara Osterfeld                                       0       1             0
# Grady Evans                                          0       0             0
# Alma Sejdovic                                        0       1             0
# Jacob Honore                                         0       0             0
# Alberto Muinos Olego                                 1       1             0
# Josef Kandelan                                       0       0             0
# Marie-Morgane Kergrohenn                             0       0             0
#
#                                 Wine tasting  Work / Life balance  \
# Name
# Ana Tojeiro                                0                    0
# Yosephine Gita Asaria Hutauruk             0                    0
# Nikolaos Papadopoulos                      0                    0
# Lucia Caiata                               0                    1
# Radhika Paliwal                            0                    0
# Gabriele Antonio Innocenti                 1                    0
# Basel Iskandarani                          0                    0
# Eva Roussou                                0                    1
# Gurmeet Johal                              0                    1
# Felix Neulinger                            0                    0
# Tony Lenssens                              1                    0
# Laurene Courreges                          0                    0
# Cameron Chestnut                           0                    0
# Rhiona Pikeur                              0                    0
# Diyar Alyasiri                             0                    0
# Alex Hoecht                                0                    0
# Francesco Carmine Carbone                  0                    0
# Chiara Pannacci                            0                    0
# Peter Morris                               0                    0
# Sierra Tokanel                             0                    0
# Brian O'Sullivan                           0                    0
# Maria Camila Marin                         0                    0
# Eda Akturk                                 0                    0
# Nish Solanki                               0                    0
# Andrew LaBrie                              1                    1
# Yara Shams El Din                          0                    0
# Ryan Greenwood                             0                    0
# Flora Shi                                  0                    0
# Mathias Cronjager                          0                    0
# Paige Patterson                            0                    1
# Seda Gulbahar                              0                    0
# Nico Hoffmann                              0                    0
# Florian Herkert                            0                    0
# Daniel Dabrowski                           0                    0
# Max Amato                                  0                    0
# Anne Madariaga                             0                    0
# Jennifer Seo                               0                    0
# Deepti Babber                              0                    0
# Josh Ingeniero                             0                    0
# Maria Garcia Maresca                       0                    0
# Camillo Dall'Oglio                         0                    0
# Gaia Bergamaschi                           0                    0
# Jamie Watts                                0                    0
# Alvin Lau                                  0                    0
# Andre Winkfield                            0                    0
# Timi Omoyajowo                             0                    0
# Iaroslav Bondarenko                        0                    0
# Nicola Chiarappa                           1                    0
# Wu Ziyu                                    0                    0
# Jennifer Goehler                           0                    0
# Rami Alfadel                               0                    1
# J. Hunter Roman                            0                    0
# Jara Osterfeld                             0                    0
# Grady Evans                                0                    0
# Alma Sejdovic                              0                    0
# Jacob Honore                               0                    0
# Alberto Muinos Olego                       0                    1
# Josef Kandelan                             0                    1
# Marie-Morgane Kergrohenn                   1                    0
#
#                                 Working out  day2day_advice  general_advice  \
# Name
# Ana Tojeiro                               0               0               1
# Yosephine Gita Asaria Hutauruk            1               1               1
# Nikolaos Papadopoulos                     0               0               1
# Lucia Caiata                              0               0               1
# Radhika Paliwal                           1               1               1
# Gabriele Antonio Innocenti                0               1               0
# Basel Iskandarani                         0               1               1
# Eva Roussou                               1               1               1
# Gurmeet Johal                             0               1               1
# Felix Neulinger                           0               1               1
# Tony Lenssens                             0               0               1
# Laurene Courreges                         0               1               1
# Cameron Chestnut                          1               1               0
# Rhiona Pikeur                             0               0               1
# Diyar Alyasiri                            0               0               0
# Alex Hoecht                               0               0               0
# Francesco Carmine Carbone                 0               0               0
# Chiara Pannacci                           1               1               0
# Peter Morris                              0               0               0
# Sierra Tokanel                            1               0               0
# Brian O'Sullivan                          1               0               0
# Maria Camila Marin                        1               0               1
# Eda Akturk                                0               0               0
# Nish Solanki                              0               0               1
# Andrew LaBrie                             1               0               1
# Yara Shams El Din                         0               0               1
# Ryan Greenwood                            1               1               1
# Flora Shi                                 0               1               1
# Mathias Cronjager                         0               0               1
# Paige Patterson                           0               0               1
# Seda Gulbahar                             0               0               1
# Nico Hoffmann                             0               0               1
# Florian Herkert                           1               1               0
# Daniel Dabrowski                          0               0               0
# Max Amato                                 0               1               1
# Anne Madariaga                            0               1               1
# Jennifer Seo                              0               0               1
# Deepti Babber                             0               0               0
# Josh Ingeniero                            0               0               1
# Maria Garcia Maresca                      0               0               1
# Camillo Dall'Oglio                        0               0               1
# Gaia Bergamaschi                          0               0               0
# Jamie Watts                               0               0               1
# Alvin Lau                                 1               1               1
# Andre Winkfield                           0               1               0
# Timi Omoyajowo                            0               0               0
# Iaroslav Bondarenko                       0               1               0
# Nicola Chiarappa                          0               0               0
# Wu Ziyu                                   0               1               0
# Jennifer Goehler                          0               0               0
# Rami Alfadel                              0               1               0
# J. Hunter Roman                           0               1               0
# Jara Osterfeld                            0               0               1
# Grady Evans                               0               1               1
# Alma Sejdovic                             0               1               0
# Jacob Honore                              0               1               1
# Alberto Muinos Olego                      0               1               1
# Josef Kandelan                            0               1               1
# Marie-Morgane Kergrohenn                  0               1               0
#
#                                 own_advice  specific_advice
# Name
# Ana Tojeiro                              1                0
# Yosephine Gita Asaria Hutauruk           1                0
# Nikolaos Papadopoulos                    1                0
# Lucia Caiata                             1                0
# Radhika Paliwal                          1                1
# Gabriele Antonio Innocenti               1                0
# Basel Iskandarani                        1                1
# Eva Roussou                              1                0
# Gurmeet Johal                            1                1
# Felix Neulinger                          1                1
# Tony Lenssens                            1                0
# Laurene Courreges                        1                0
# Cameron Chestnut                         1                0
# Rhiona Pikeur                            1                0
# Diyar Alyasiri                           1                1
# Alex Hoecht                              1                1
# Francesco Carmine Carbone                1                1
# Chiara Pannacci                          1                1
# Peter Morris                             1                1
# Sierra Tokanel                           1                1
# Brian O'Sullivan                         1                1
# Maria Camila Marin                       1                1
# Eda Akturk                               1                1
# Nish Solanki                             1                0
# Andrew LaBrie                            1                0
# Yara Shams El Din                        1                0
# Ryan Greenwood                           1                1
# Flora Shi                                1                0
# Mathias Cronjager                        1                0
# Paige Patterson                          1                0
# Seda Gulbahar                            1                0
# Nico Hoffmann                            1                0
# Florian Herkert                          1                0
# Daniel Dabrowski                         1                1
# Max Amato                                1                0
# Anne Madariaga                           1                0
# Jennifer Seo                             1                1
# Deepti Babber                            1                1
# Josh Ingeniero                           1                0
# Maria Garcia Maresca                     1                1
# Camillo Dall'Oglio                       1                1
# Gaia Bergamaschi                         1                1
# Jamie Watts                              1                0
# Alvin Lau                                1                0
# Andre Winkfield                          1                0
# Timi Omoyajowo                           1                1
# Iaroslav Bondarenko                      1                0
# Nicola Chiarappa                         1                1
# Wu Ziyu                                  1                1
# Jennifer Goehler                         1                1
# Rami Alfadel                             1                0
# J. Hunter Roman                          1                0
# Jara Osterfeld                           1                0
# Grady Evans                              1                1
# Alma Sejdovic                            1                1
# Jacob Honore                             1                0
# Alberto Muinos Olego                     1                1
# Josef Kandelan                           1                1
# Marie-Morgane Kergrohenn                 1                0
#
# [59 rows x 62 columns]

# %%
for i in strengths_mentor:
    if i != strengths_mentee:
        print(i)
# Out:
# Time management
# Team building
# Influencing
# Creativity / innovation
# Negotiating
# Technical knowledge
# Productivity
# Design thinking
# Cross-architecture
# Competitive strategy
# Effective listening
# Prioritization
# Communications (public speaking)
# Recognition
# Empowerment
# Finance
# Change management
# Providing feedback
# Customer interaction
# Personal Brand
# Work / Life balance
# Crucial conversations
# Transition career path
# Delegating
# Story telling
# Decision making
# Accountability
# Critical thinking
# Social Media
# Coaching
# Goal setting
# Collaboration
# Rapport Building

# %%
list(df_onehot_mentor.isin([3]).any())
# Out:
# [False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False,
#  False]

# %%
set(df_mentee["What are you most likely to want out of this mentoring engagement?"])
# Out:
# {'Form a strategic plan on how to become the best (or the mindset that will help me do);',
#  'General strategic career advice;',
#  'General strategic career advice;How one could maximize the talent and potential;',
#  'General strategic career advice;Specific career advice to prepare for next role;',
#  'General strategic career advice;Specific career advice to prepare for next role;Tactical day to day situations & problem solving;',
#  'General strategic career advice;Tactical day to day situations & problem solving;',
#  'General strategic career advice;Tactical day to day situations & problem solving;How to build better relationships with customers and partners / ;',
#  'General strategic career advice;Tactical day to day situations & problem solving;Specific career advice to prepare for next role;',
#  'Looking to hear about how they handle pressure, situational experiences (wins and losses) Want to hear their perspective on how to be a good team player Want to hear their thoughts on market changes and where tech, energy and agriculture are headed. ;General strategic career advice;',
#  'Specific career advice to prepare for next role;',
#  'Specific career advice to prepare for next role;Tactical day to day situations & problem solving;',
#  'Tactical day to day situations & problem solving;',
#  'Tactical day to day situations & problem solving;General strategic career advice;',
#  'Tactical day to day situations & problem solving;General strategic career advice;Specific career advice to prepare for next role;Anything that they wish they had known in my situation;',
#  'Tactical day to day situations & problem solving;Specific career advice to prepare for next role;'}

# %%
############ test for keywords


#set(df["What are your personal interests?"])
test = []
for i in df["What are your early expectations from this mentoring engagement?"]:
    test.append(i)
test
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-416-10d77c41b3f8> in <module>
#       4 #set(df["What are your personal interests?"])
#       5 test = []
# ----> 6 for i in df["What are your early expectations from this mentoring engagement?"]:
#       7     test.append(i)
#       8 test
#
# NameError: name 'df' is not defined

# %%
# function that combines multiple one hot encoded columns into a single column and renames it
def combine_cols(df, combine_name, combine_cols, replace="no"):
    df_output = df
    if replace == "no":
        df_output[combine_name] = 0  
    for col in combine_cols:
        df_output[combine_name] + df[col]
        #df.drop(col, axis=1, inplace=True)
    count = 0
    for number in df_output[combine_name]:
        if number > 1:
            print("yep")
            df_output.loc[df_output.index[count], combine_name] = 1
            number = 1
            count += 1
    return df_output

# %%
# keyword extraction

from rake_nltk import Rake

r = Rake(max_length=1) # Uses stopwords for english from NLTK, and all puntuation characters.

r.extract_keywords_from_text(test[4])

r.get_ranked_phrases() # To get keyword phrases ranked highest to lowest.
